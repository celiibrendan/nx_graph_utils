# %%
import networkx as nx
import graph_experiments_utils as gu
# %matplotlib inline

# %% [markdown]
# # Available Graphs

# %%
#graph options
gu.watts_strogatz_graph_smallworld_random_location
gu.random_tree_random_location
gu.erdos_renyi_random_location
# Out:
# <function graph_experiments_utils.erdos_renyi_random_location(n, p)>

# %% [markdown]
# # Run the experiment

# %%
from graph_experiments_utils import *

# %%
functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = erdos_renyi_random_location

loop_1 = dict(n=[10,20,50,100,150])
loop_2 = dict(p=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4])
iterable_loops = [loop_1,loop_2]
n_iterations = 5


data_structure_erdos = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = random_tree_random_location

loop_1 = dict(n=[10,15,20,20,40,50,60,80,100,120,150,200])
iterable_loops = [loop_1]
n_iterations = 5


data_structure_tree = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = watts_strogatz_graph_smallworld_random_location

loop_1 = dict(n=[10,20,50,100,150])
loop_2 = dict(p=[0.1,0.4,0.6])
loop_3 = dict(k=[2,4,8])
iterable_loops = [loop_1,loop_2,loop_3]
n_iterations = 5


data_structure_smallworld = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %% [markdown]
# # Visualize some of the graphs

# %%
data_structure_erdos.keys()
# Out:
# dict_keys(['erdos_renyi_random_location:_n=10_p=0.05', 'erdos_renyi_random_location:_n=10_p=0.10', 'erdos_renyi_random_location:_n=10_p=0.15', 'erdos_renyi_random_location:_n=10_p=0.20', 'erdos_renyi_random_location:_n=10_p=0.25', 'erdos_renyi_random_location:_n=10_p=0.30', 'erdos_renyi_random_location:_n=10_p=0.35', 'erdos_renyi_random_location:_n=10_p=0.40', 'erdos_renyi_random_location:_n=20_p=0.05', 'erdos_renyi_random_location:_n=20_p=0.10', 'erdos_renyi_random_location:_n=20_p=0.15', 'erdos_renyi_random_location:_n=20_p=0.20', 'erdos_renyi_random_location:_n=20_p=0.25', 'erdos_renyi_random_location:_n=20_p=0.30', 'erdos_renyi_random_location:_n=20_p=0.35', 'erdos_renyi_random_location:_n=20_p=0.40', 'erdos_renyi_random_location:_n=50_p=0.05', 'erdos_renyi_random_location:_n=50_p=0.10', 'erdos_renyi_random_location:_n=50_p=0.15', 'erdos_renyi_random_location:_n=50_p=0.20', 'erdos_renyi_random_location:_n=50_p=0.25', 'erdos_renyi_random_location:_n=50_p=0.30', 'erdos_renyi_random_location:_n=50_p=0.35', 'erdos_renyi_random_location:_n=50_p=0.40', 'erdos_renyi_random_location:_n=100_p=0.05', 'erdos_renyi_random_location:_n=100_p=0.10', 'erdos_renyi_random_location:_n=100_p=0.15', 'erdos_renyi_random_location:_n=100_p=0.20', 'erdos_renyi_random_location:_n=100_p=0.25', 'erdos_renyi_random_location:_n=100_p=0.30', 'erdos_renyi_random_location:_n=100_p=0.35', 'erdos_renyi_random_location:_n=100_p=0.40', 'erdos_renyi_random_location:_n=150_p=0.05', 'erdos_renyi_random_location:_n=150_p=0.10', 'erdos_renyi_random_location:_n=150_p=0.15', 'erdos_renyi_random_location:_n=150_p=0.20', 'erdos_renyi_random_location:_n=150_p=0.25', 'erdos_renyi_random_location:_n=150_p=0.30', 'erdos_renyi_random_location:_n=150_p=0.35', 'erdos_renyi_random_location:_n=150_p=0.40'])

# %%
current_data_structure = data_structure_erdos

graph_1_name = list(current_data_structure.keys())[13]
example_graph_1 = current_data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'erdos_renyi_random_location:_n=20_p=0.30')

# %%
current_data_structure = data_structure_tree

graph_1_name = list(current_data_structure.keys())[2]
example_graph_1 = current_data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'random_tree_random_location:_n=20')

# %%
current_data_structure = data_structure_smallworld

graph_1_name = list(current_data_structure.keys())[10]
example_graph_1 = current_data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'watts_strogatz_graph_smallworld_random_location:_n=20_p=0.10_k=4')

# %% [markdown]
# # Compare Graph Statistics

# %%
data_structure_total = dict()
dict_to_combine = [data_structure_erdos,data_structure_smallworld,data_structure_tree,]
for dk in dict_to_combine:
    data_structure_total.update(dk)
df = table_comparison_statistics(data_structure_total)

# %%
df
# Out:
#                                       graphs    n   k     p  n_nodes  n_edges  \
# 0   erdos_renyi_random_location:_n=10_p=0.05   10 NaN  0.05       10        3
# 1   erdos_renyi_random_location:_n=10_p=0.10   10 NaN  0.10       10        3
# 2   erdos_renyi_random_location:_n=10_p=0.15   10 NaN  0.15       10       10
# 3   erdos_renyi_random_location:_n=10_p=0.20   10 NaN  0.20       10        8
# 4   erdos_renyi_random_location:_n=10_p=0.25   10 NaN  0.25       10       12
# ..                                       ...  ...  ..   ...      ...      ...
# 91         random_tree_random_location:_n=80   80 NaN   NaN       80       79
# 92        random_tree_random_location:_n=100  100 NaN   NaN      100       99
# 93        random_tree_random_location:_n=120  120 NaN   NaN      120      119
# 94        random_tree_random_location:_n=150  150 NaN   NaN      150      149
# 95        random_tree_random_location:_n=200  200 NaN   NaN      200      199
#
#     n_triangles  transitivity  node_connectivity  size_maximum_clique  \
# 0           0.0      0.000000                0.0                  1.8
# 1           0.0      0.000000                0.0                  2.0
# 2           0.4      0.054545                0.0                  2.2
# 3           1.2      0.216234                0.0                  2.6
# 4           1.8      0.221688                0.0                  2.8
# ..          ...           ...                ...                  ...
# 91          0.0      0.000000                1.0                  2.0
# 92          0.0      0.000000                1.0                  2.0
# 93          0.0      0.000000                1.0                  2.0
# 94          0.0      0.000000                1.0                  2.0
# 95          0.0      0.000000                1.0                  2.0
#
#     n_maximal_cliques  min_weighted_vertex_cover_len  tree_number  \
# 0                 8.8                            3.2          0.8
# 1                 8.4                            4.8          1.0
# 2                 8.4                            6.0          1.4
# 3                 8.4                            5.6          1.6
# 4                 8.6                            7.6          2.2
# ..                ...                            ...          ...
# 91               79.0                           64.4          1.0
# 92               99.0                           81.6          1.0
# 93              119.0                           97.6          1.0
# 94              149.0                          121.2          1.0
# 95              199.0                          160.4          1.0
#
#                      graph_type
# 0   erdos_renyi_random_location
# 1   erdos_renyi_random_location
# 2   erdos_renyi_random_location
# 3   erdos_renyi_random_location
# 4   erdos_renyi_random_location
# ..                          ...
# 91  random_tree_random_location
# 92  random_tree_random_location
# 93  random_tree_random_location
# 94  random_tree_random_location
# 95  random_tree_random_location
#
# [96 rows x 14 columns]

# %%
from importlib import reload  # Python 3.4+ only.
import graph_experiments_utils
graph_experiments_utils = reload(graph_experiments_utils)

# %%
returned_df, (fig,ax) = graph_experiments_utils.plot_df_values(df,index_restriction=[],
               x_column="n_edges",
               y_column = "n",
               z_column = "n_triangles",
                grouping=dict(graph_type=dict(exact=[])),
               plot_type="scatter",
               title="Triangles vs. Node Count",
              #value_restriction=" n_edges > 10 ",
                return_fig_ax=True,
                return_plotted_df_table=True
                                )
# Update the plot
plt.show()
# Out:
# returning figure and ax

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
returned_df
# Out:
#                                                graphs    n     k     p  \
# 0            erdos_renyi_random_location:_n=10_p=0.05   10  None  0.05
# 1            erdos_renyi_random_location:_n=10_p=0.10   10  None   0.1
# 2            erdos_renyi_random_location:_n=10_p=0.15   10  None  0.15
# 3            erdos_renyi_random_location:_n=10_p=0.20   10  None   0.2
# 4            erdos_renyi_random_location:_n=10_p=0.25   10  None  0.25
# 5            erdos_renyi_random_location:_n=10_p=0.30   10  None   0.3
# 6            erdos_renyi_random_location:_n=10_p=0.35   10  None  0.35
# 7            erdos_renyi_random_location:_n=10_p=0.40   10  None   0.4
# 8            erdos_renyi_random_location:_n=20_p=0.05   20  None  0.05
# 9            erdos_renyi_random_location:_n=20_p=0.10   20  None   0.1
# 10           erdos_renyi_random_location:_n=20_p=0.15   20  None  0.15
# 11           erdos_renyi_random_location:_n=20_p=0.20   20  None   0.2
# 12           erdos_renyi_random_location:_n=20_p=0.25   20  None  0.25
# 13           erdos_renyi_random_location:_n=20_p=0.30   20  None   0.3
# 14           erdos_renyi_random_location:_n=20_p=0.35   20  None  0.35
# 15           erdos_renyi_random_location:_n=20_p=0.40   20  None   0.4
# 16           erdos_renyi_random_location:_n=50_p=0.05   50  None  0.05
# 17           erdos_renyi_random_location:_n=50_p=0.10   50  None   0.1
# 18           erdos_renyi_random_location:_n=50_p=0.15   50  None  0.15
# 19           erdos_renyi_random_location:_n=50_p=0.20   50  None   0.2
# 20           erdos_renyi_random_location:_n=50_p=0.25   50  None  0.25
# 21           erdos_renyi_random_location:_n=50_p=0.30   50  None   0.3
# 22           erdos_renyi_random_location:_n=50_p=0.35   50  None  0.35
# 23           erdos_renyi_random_location:_n=50_p=0.40   50  None   0.4
# 24          erdos_renyi_random_location:_n=100_p=0.05  100  None  0.05
# 25          erdos_renyi_random_location:_n=100_p=0.10  100  None   0.1
# 26          erdos_renyi_random_location:_n=100_p=0.15  100  None  0.15
# 27          erdos_renyi_random_location:_n=100_p=0.20  100  None   0.2
# 28          erdos_renyi_random_location:_n=100_p=0.25  100  None  0.25
# 29          erdos_renyi_random_location:_n=100_p=0.30  100  None   0.3
# 30          erdos_renyi_random_location:_n=100_p=0.35  100  None  0.35
# 31          erdos_renyi_random_location:_n=100_p=0.40  100  None   0.4
# 32          erdos_renyi_random_location:_n=150_p=0.05  150  None  0.05
# 33          erdos_renyi_random_location:_n=150_p=0.10  150  None   0.1
# 34          erdos_renyi_random_location:_n=150_p=0.15  150  None  0.15
# 35          erdos_renyi_random_location:_n=150_p=0.20  150  None   0.2
# 36          erdos_renyi_random_location:_n=150_p=0.25  150  None  0.25
# 37          erdos_renyi_random_location:_n=150_p=0.30  150  None   0.3
# 38          erdos_renyi_random_location:_n=150_p=0.35  150  None  0.35
# 39          erdos_renyi_random_location:_n=150_p=0.40  150  None   0.4
# 0                   random_tree_random_location:_n=10   10  None  None
# 1                   random_tree_random_location:_n=15   15  None  None
# 2                   random_tree_random_location:_n=20   20  None  None
# 3                   random_tree_random_location:_n=40   40  None  None
# 4                   random_tree_random_location:_n=50   50  None  None
# 5                   random_tree_random_location:_n=60   60  None  None
# 6                   random_tree_random_location:_n=80   80  None  None
# 7                  random_tree_random_location:_n=100  100  None  None
# 8                  random_tree_random_location:_n=120  120  None  None
# 9                  random_tree_random_location:_n=150  150  None  None
# 10                 random_tree_random_location:_n=200  200  None  None
# 0   watts_strogatz_graph_smallworld_random_locatio...   10     2   0.1
# 1   watts_strogatz_graph_smallworld_random_locatio...   10     4   0.1
# 2   watts_strogatz_graph_smallworld_random_locatio...   10     8   0.1
# 3   watts_strogatz_graph_smallworld_random_locatio...   10     2   0.4
# 4   watts_strogatz_graph_smallworld_random_locatio...   10     4   0.4
# 5   watts_strogatz_graph_smallworld_random_locatio...   10     8   0.4
# 6   watts_strogatz_graph_smallworld_random_locatio...   10     2   0.6
# 7   watts_strogatz_graph_smallworld_random_locatio...   10     4   0.6
# 8   watts_strogatz_graph_smallworld_random_locatio...   10     8   0.6
# 9   watts_strogatz_graph_smallworld_random_locatio...   20     2   0.1
# 10  watts_strogatz_graph_smallworld_random_locatio...   20     4   0.1
# 11  watts_strogatz_graph_smallworld_random_locatio...   20     8   0.1
# 12  watts_strogatz_graph_smallworld_random_locatio...   20     2   0.4
# 13  watts_strogatz_graph_smallworld_random_locatio...   20     4   0.4
# 14  watts_strogatz_graph_smallworld_random_locatio...   20     8   0.4
# 15  watts_strogatz_graph_smallworld_random_locatio...   20     2   0.6
# 16  watts_strogatz_graph_smallworld_random_locatio...   20     4   0.6
# 17  watts_strogatz_graph_smallworld_random_locatio...   20     8   0.6
# 18  watts_strogatz_graph_smallworld_random_locatio...   50     2   0.1
# 19  watts_strogatz_graph_smallworld_random_locatio...   50     4   0.1
# 20  watts_strogatz_graph_smallworld_random_locatio...   50     8   0.1
# 21  watts_strogatz_graph_smallworld_random_locatio...   50     2   0.4
# 22  watts_strogatz_graph_smallworld_random_locatio...   50     4   0.4
# 23  watts_strogatz_graph_smallworld_random_locatio...   50     8   0.4
# 24  watts_strogatz_graph_smallworld_random_locatio...   50     2   0.6
# 25  watts_strogatz_graph_smallworld_random_locatio...   50     4   0.6
# 26  watts_strogatz_graph_smallworld_random_locatio...   50     8   0.6
# 27  watts_strogatz_graph_smallworld_random_locatio...  100     2   0.1
# 28  watts_strogatz_graph_smallworld_random_locatio...  100     4   0.1
# 29  watts_strogatz_graph_smallworld_random_locatio...  100     8   0.1
# 30  watts_strogatz_graph_smallworld_random_locatio...  100     2   0.4
# 31  watts_strogatz_graph_smallworld_random_locatio...  100     4   0.4
# 32  watts_strogatz_graph_smallworld_random_locatio...  100     8   0.4
# 33  watts_strogatz_graph_smallworld_random_locatio...  100     2   0.6
# 34  watts_strogatz_graph_smallworld_random_locatio...  100     4   0.6
# 35  watts_strogatz_graph_smallworld_random_locatio...  100     8   0.6
# 36  watts_strogatz_graph_smallworld_random_locatio...  150     2   0.1
# 37  watts_strogatz_graph_smallworld_random_locatio...  150     4   0.1
# 38  watts_strogatz_graph_smallworld_random_locatio...  150     8   0.1
# 39  watts_strogatz_graph_smallworld_random_locatio...  150     2   0.4
# 40  watts_strogatz_graph_smallworld_random_locatio...  150     4   0.4
# 41  watts_strogatz_graph_smallworld_random_locatio...  150     8   0.4
# 42  watts_strogatz_graph_smallworld_random_locatio...  150     2   0.6
# 43  watts_strogatz_graph_smallworld_random_locatio...  150     4   0.6
# 44  watts_strogatz_graph_smallworld_random_locatio...  150     8   0.6
#
#     n_nodes  n_edges  n_triangles  transitivity  node_connectivity  \
# 0        10        3          0.0      0.000000                0.0
# 1        10        3          0.0      0.000000                0.0
# 2        10       10          0.4      0.054545                0.0
# 3        10        8          1.2      0.216234                0.0
# 4        10       12          1.8      0.221688                0.0
# 5        10       16          2.4      0.258416                0.4
# 6        10       19          6.0      0.355643                1.2
# 7        10       15          3.8      0.307815                0.8
# 8        20       10          0.0      0.000000                0.0
# 9        20       19          0.6      0.053456                0.0
# 10       20       29          4.6      0.193642                0.6
# 11       20       34          6.8      0.149380                1.0
# 12       20       50         22.8      0.261399                1.8
# 13       20       60         29.0      0.290813                2.2
# 14       20       73         52.6      0.360890                2.8
# 15       20       72         73.8      0.383205                4.0
# 16       50       60          1.8      0.036465                0.0
# 17       50      123         24.0      0.116679                1.0
# 18       50      175         67.4      0.150052                2.8
# 19       50      256        195.2      0.219044                4.2
# 20       50      300        285.2      0.242620                5.6
# 21       50      401        519.0      0.297342                7.8
# 22       50      426        873.0      0.354981                8.4
# 23       50      501       1247.4      0.395572               13.2
# 24      100      266         20.6      0.049762                1.0
# 25      100      495        163.0      0.100133                3.2
# 26      100      750        556.0      0.149489                6.0
# 27      100     1013       1347.4      0.203689               11.0
# 28      100     1264       2483.0      0.247711               14.8
# 29      100     1538       4399.0      0.299595               19.2
# 30      100     1730       6796.8      0.348780               24.0
# 31      100     2026      10442.0      0.400724               28.8
# 32      150      529         62.6      0.046242                1.2
# 33      150     1141        585.0      0.102309                5.8
# 34      150     1619       1849.0      0.148711               11.6
# 35      150     2196       4469.0      0.201430               19.2
# 36      150     2764       8277.6      0.247419               21.4
# 37      150     3449      15234.0      0.301883               28.6
# 38      150     3828      22988.8      0.346994               33.6
# 39      150     4426      35365.6      0.399991               45.4
# 0        10        9          0.0      0.000000                1.0
# 1        15       14          0.0      0.000000                1.0
# 2        20       19          0.0      0.000000                1.0
# 3        40       39          0.0      0.000000                1.0
# 4        50       49          0.0      0.000000                1.0
# 5        60       59          0.0      0.000000                1.0
# 6        80       79          0.0      0.000000                1.0
# 7       100       99          0.0      0.000000                1.0
# 8       120      119          0.0      0.000000                1.0
# 9       150      149          0.0      0.000000                1.0
# 10      200      199          0.0      0.000000                1.0
# 0        10       10          0.0      0.000000                1.6
# 1        10       20          9.8      0.480381                2.8
# 2        10       40         82.6      0.876193                6.8
# 3        10       10          0.6      0.112857                1.0
# 4        10       20          8.0      0.369964                2.6
# 5        10       40         83.4      0.882792                6.8
# 6        10       10          0.4      0.075294                1.0
# 7        10       20          8.8      0.395000                2.2
# 8        10       40         82.8      0.878355                7.0
# 9        20       20          0.0      0.000000                1.0
# 10       20       40         16.8      0.405622                2.2
# 11       20       80         96.8      0.509696                6.0
# 12       20       20          0.2      0.019355                1.0
# 13       20       40          7.2      0.159302                2.0
# 14       20       80         76.6      0.399469                5.6
# 15       20       20          0.4      0.046154                0.8
# 16       20       40          6.8      0.150342                2.0
# 17       20       80         75.2      0.386412                5.0
# 18       50       50          0.0      0.000000                1.0
# 19       50      100         40.2      0.392879                2.0
# 20       50      200        228.4      0.483302                5.8
# 21       50       50          0.2      0.008333                0.4
# 22       50      100         16.4      0.145301                2.0
# 23       50      200        111.0      0.226163                4.8
# 24       50       50          1.2      0.052584                0.4
# 25       50      100          9.6      0.084697                2.0
# 26       50      200         79.6      0.162114                4.6
# 27      100      100          0.0      0.000000                0.6
# 28      100      200         76.8      0.373844                2.0
# 29      100      400        443.6      0.468900                5.6
# 30      100      100          0.4      0.008955                0.4
# 31      100      200         25.2      0.114359                2.0
# 32      100      400        176.0      0.180743                4.8
# 33      100      100          1.0      0.020827                0.2
# 34      100      200         12.8      0.056221                2.0
# 35      100      400         94.0      0.095753                4.6
# 36      150      150          0.0      0.000000                0.6
# 37      150      300        110.0      0.355642                2.0
# 38      150      600        678.6      0.478514                5.4
# 39      150      150          0.0      0.000000                0.8
# 40      150      300         38.4      0.115108                2.0
# 41      150      600        229.8      0.156882                4.2
# 42      150      150          0.4      0.005857                0.4
# 43      150      300         15.6      0.045634                2.0
# 44      150      600        121.8      0.081825                4.0
#
#     size_maximum_clique  n_maximal_cliques  min_weighted_vertex_cover_len  \
# 0                   1.8                8.8                            3.2
# 1                   2.0                8.4                            4.8
# 2                   2.2                8.4                            6.0
# 3                   2.6                8.4                            5.6
# 4                   2.8                8.6                            7.6
# 5                   3.0                9.0                            6.8
# 6                   3.2               10.0                            8.4
# 7                   3.2                9.6                            9.2
# 8                   2.0               17.0                            9.6
# 9                   2.6               20.4                           15.6
# 10                  3.2               20.8                           14.8
# 11                  3.2               28.8                           16.8
# 12                  3.8               30.6                           17.6
# 13                  3.8               32.6                           17.2
# 14                  4.2               36.2                           17.6
# 15                  4.6               42.4                           18.0
# 16                  3.0               59.6                           33.6
# 17                  3.4               92.4                           43.6
# 18                  3.8              119.6                           45.6
# 19                  4.6              167.6                           47.2
# 20                  4.4              205.6                           48.0
# 21                  5.0              276.8                           47.6
# 22                  5.6              375.2                           47.6
# 23                  6.0              491.4                           49.6
# 24                  3.0              218.8                           84.8
# 25                  4.0              333.4                           94.0
# 26                  4.4              529.0                           94.4
# 27                  5.2              849.8                           96.8
# 28                  5.6             1253.8                           98.0
# 29                  6.0             2019.6                           98.0
# 30                  7.0             3097.6                           97.6
# 31                  7.2             5260.2                           98.4
# 32                  3.0              454.2                          135.6
# 33                  4.0              764.6                          144.4
# 34                  5.0             1404.6                          146.4
# 35                  5.8             2464.6                          146.4
# 36                  6.2             3982.4                          146.8
# 37                  7.0             7657.6                          147.6
# 38                  7.4            12896.2                          148.0
# 39                  8.0            25495.8                          148.4
# 0                   2.0                9.0                            7.6
# 1                   2.0               14.0                           12.0
# 2                   2.0               19.0                           17.2
# 3                   2.0               39.0                           32.4
# 4                   2.0               49.0                           41.6
# 5                   2.0               59.0                           48.4
# 6                   2.0               79.0                           64.4
# 7                   2.0               99.0                           81.6
# 8                   2.0              119.0                           97.6
# 9                   2.0              149.0                          121.2
# 10                  2.0              199.0                          160.4
# 0                   2.0               10.0                            9.6
# 1                   3.2                9.8                           10.0
# 2                   6.6               10.0                           10.0
# 3                   2.6                8.8                            7.6
# 4                   3.0               11.0                            8.4
# 5                   7.2                6.4                           10.0
# 6                   2.4                9.2                            7.6
# 7                   3.6               10.0                            8.8
# 8                   7.0                6.8                           10.0
# 9                   2.0               20.0                           18.8
# 10                  3.0               21.2                           18.8
# 11                  5.0               31.2                           19.6
# 12                  2.2               19.6                           17.6
# 13                  3.0               28.6                           18.0
# 14                  4.2               44.4                           19.6
# 15                  2.4               19.2                           16.4
# 16                  3.0               29.8                           19.2
# 17                  4.2               48.0                           19.2
# 18                  2.0               50.0                           47.6
# 19                  3.0               53.4                           49.2
# 20                  5.0               76.2                           50.0
# 21                  2.2               49.6                           42.8
# 22                  3.4               74.6                           47.2
# 23                  4.6              115.6                           48.8
# 24                  2.8               47.6                           39.2
# 25                  3.0               83.2                           45.6
# 26                  4.0              123.8                           48.8
# 27                  2.0              100.0                           96.4
# 28                  3.2              109.6                           99.6
# 29                  5.0              155.6                          100.0
# 30                  2.4               99.2                           84.4
# 31                  3.2              158.6                           96.8
# 32                  4.6              248.4                           98.4
# 33                  2.8               98.0                           81.2
# 34                  3.0              176.2                           91.6
# 35                  4.0              278.6                           97.2
# 36                  2.0              150.0                          142.8
# 37                  3.4              167.0                          150.0
# 38                  5.4              227.0                          149.6
# 39                  2.0              150.0                          131.2
# 40                  3.2              238.0                          140.8
# 41                  4.4              389.0                          148.4
# 42                  2.4              149.2                          121.2
# 43                  3.0              271.4                          136.0
# 44                  4.2              445.8                          146.0
#
#     tree_number                                       graph_type
# 0           0.8                      erdos_renyi_random_location
# 1           1.0                      erdos_renyi_random_location
# 2           1.4                      erdos_renyi_random_location
# 3           1.6                      erdos_renyi_random_location
# 4           2.2                      erdos_renyi_random_location
# 5           2.2                      erdos_renyi_random_location
# 6           3.4                      erdos_renyi_random_location
# 7           2.8                      erdos_renyi_random_location
# 8           1.0                      erdos_renyi_random_location
# 9           2.4                      erdos_renyi_random_location
# 10          3.0                      erdos_renyi_random_location
# 11          5.6                      erdos_renyi_random_location
# 12          6.6                      erdos_renyi_random_location
# 13          7.4                      erdos_renyi_random_location
# 14          9.0                      erdos_renyi_random_location
# 15         10.0                      erdos_renyi_random_location
# 16          4.2                      erdos_renyi_random_location
# 17         14.2                      erdos_renyi_random_location
# 18         21.0                      erdos_renyi_random_location
# 19         26.2                      erdos_renyi_random_location
# 20         28.4                      erdos_renyi_random_location
# 21         31.2                      erdos_renyi_random_location
# 22         33.8                      erdos_renyi_random_location
# 23         35.4                      erdos_renyi_random_location
# 24         28.2                      erdos_renyi_random_location
# 25         49.0                      erdos_renyi_random_location
# 26         61.4                      erdos_renyi_random_location
# 27         68.2                      erdos_renyi_random_location
# 28         73.4                      erdos_renyi_random_location
# 29         76.4                      erdos_renyi_random_location
# 30         80.6                      erdos_renyi_random_location
# 31         83.0                      erdos_renyi_random_location
# 32         60.0                      erdos_renyi_random_location
# 33         91.8                      erdos_renyi_random_location
# 34        105.2                      erdos_renyi_random_location
# 35        114.2                      erdos_renyi_random_location
# 36        119.2                      erdos_renyi_random_location
# 37        124.8                      erdos_renyi_random_location
# 38        127.2                      erdos_renyi_random_location
# 39        130.8                      erdos_renyi_random_location
# 0           1.0                      random_tree_random_location
# 1           1.0                      random_tree_random_location
# 2           1.0                      random_tree_random_location
# 3           1.0                      random_tree_random_location
# 4           1.0                      random_tree_random_location
# 5           1.0                      random_tree_random_location
# 6           1.0                      random_tree_random_location
# 7           1.0                      random_tree_random_location
# 8           1.0                      random_tree_random_location
# 9           1.0                      random_tree_random_location
# 10          1.0                      random_tree_random_location
# 0           2.0  watts_strogatz_graph_smallworld_random_location
# 1           4.0  watts_strogatz_graph_smallworld_random_location
# 2           7.2  watts_strogatz_graph_smallworld_random_location
# 3           2.0  watts_strogatz_graph_smallworld_random_location
# 4           3.8  watts_strogatz_graph_smallworld_random_location
# 5           7.4  watts_strogatz_graph_smallworld_random_location
# 6           2.0  watts_strogatz_graph_smallworld_random_location
# 7           4.2  watts_strogatz_graph_smallworld_random_location
# 8           7.4  watts_strogatz_graph_smallworld_random_location
# 9           2.0  watts_strogatz_graph_smallworld_random_location
# 10          4.4  watts_strogatz_graph_smallworld_random_location
# 11         10.6  watts_strogatz_graph_smallworld_random_location
# 12          2.0  watts_strogatz_graph_smallworld_random_location
# 13          6.2  watts_strogatz_graph_smallworld_random_location
# 14         11.0  watts_strogatz_graph_smallworld_random_location
# 15          2.0  watts_strogatz_graph_smallworld_random_location
# 16          5.8  watts_strogatz_graph_smallworld_random_location
# 17         11.0  watts_strogatz_graph_smallworld_random_location
# 18          2.0  watts_strogatz_graph_smallworld_random_location
# 19          5.4  watts_strogatz_graph_smallworld_random_location
# 20         16.0  watts_strogatz_graph_smallworld_random_location
# 21          2.0  watts_strogatz_graph_smallworld_random_location
# 22         10.8  watts_strogatz_graph_smallworld_random_location
# 23         22.0  watts_strogatz_graph_smallworld_random_location
# 24          2.0  watts_strogatz_graph_smallworld_random_location
# 25         11.6  watts_strogatz_graph_smallworld_random_location
# 26         23.6  watts_strogatz_graph_smallworld_random_location
# 27          2.0  watts_strogatz_graph_smallworld_random_location
# 28          9.6  watts_strogatz_graph_smallworld_random_location
# 29         23.0  watts_strogatz_graph_smallworld_random_location
# 30          2.0  watts_strogatz_graph_smallworld_random_location
# 31         20.0  watts_strogatz_graph_smallworld_random_location
# 32         42.2  watts_strogatz_graph_smallworld_random_location
# 33          2.0  watts_strogatz_graph_smallworld_random_location
# 34         23.0  watts_strogatz_graph_smallworld_random_location
# 35         45.8  watts_strogatz_graph_smallworld_random_location
# 36          2.0  watts_strogatz_graph_smallworld_random_location
# 37         16.4  watts_strogatz_graph_smallworld_random_location
# 38         33.0  watts_strogatz_graph_smallworld_random_location
# 39          2.0  watts_strogatz_graph_smallworld_random_location
# 40         29.6  watts_strogatz_graph_smallworld_random_location
# 41         62.2  watts_strogatz_graph_smallworld_random_location
# 42          2.0  watts_strogatz_graph_smallworld_random_location
# 43         32.6  watts_strogatz_graph_smallworld_random_location
# 44         67.0  watts_strogatz_graph_smallworld_random_location
