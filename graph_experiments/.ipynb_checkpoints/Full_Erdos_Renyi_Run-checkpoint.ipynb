# %%
import graph_experiments_utils as gu
# %matplotlib inline

# %% [markdown]
# # Run the Experiment

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = erdos_renyi_random_location

loop_1 = dict(n=[10,20,50,100,150])
loop_2 = dict(p=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4])
iterable_loops = [loop_1,loop_2]
n_iterations = 2


data_structure = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %%
import pprint
pprint.pprint([data_structure[k] for k in list(data_structure.keys())[:5]],depth=4)
# Out:
# [{'attribute_list': [],
#   'example_graph': <networkx.classes.graph.Graph object at 0x7f4de9f09400>,
#   'graph_type': 'erdos_renyi_random_location',
#   'iterations': {0: {'min_weighted_vertex_cover_len': 2,
#                      'n_edges': 1,
#                      'n_maximal_cliques': 9,
#                      'n_triangles': 0.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 2,
#                      'transitivity': 0,
#                      'tree_number': 1},
#                  1: {'min_weighted_vertex_cover_len': 6,
#                      'n_edges': 3,
#                      'n_maximal_cliques': 7,
#                      'n_triangles': 0.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 2,
#                      'transitivity': 0,
#                      'tree_number': 1}},
#   'n_edges': 1,
#   'n_iterations': 2,
#   'n_nodes': 10,
#   'parameters': {'n': 10, 'p': 0.05}},
#  {'attribute_list': [],
#   'example_graph': <networkx.classes.graph.Graph object at 0x7f4de9f09518>,
#   'graph_type': 'erdos_renyi_random_location',
#   'iterations': {0: {'min_weighted_vertex_cover_len': 10,
#                      'n_edges': 9,
#                      'n_maximal_cliques': 7,
#                      'n_triangles': 1.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 3,
#                      'transitivity': 0.25,
#                      'tree_number': 2},
#                  1: {'min_weighted_vertex_cover_len': 8,
#                      'n_edges': 6,
#                      'n_maximal_cliques': 7,
#                      'n_triangles': 0.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 2,
#                      'transitivity': 0,
#                      'tree_number': 1}},
#   'n_edges': 9,
#   'n_iterations': 2,
#   'n_nodes': 10,
#   'parameters': {'n': 10, 'p': 0.1}},
#  {'attribute_list': [],
#   'example_graph': <networkx.classes.graph.Graph object at 0x7f4de9f09588>,
#   'graph_type': 'erdos_renyi_random_location',
#   'iterations': {0: {'min_weighted_vertex_cover_len': 4,
#                      'n_edges': 4,
#                      'n_maximal_cliques': 8,
#                      'n_triangles': 0.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 2,
#                      'transitivity': 0,
#                      'tree_number': 1},
#                  1: {'min_weighted_vertex_cover_len': 8,
#                      'n_edges': 4,
#                      'n_maximal_cliques': 6,
#                      'n_triangles': 0.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 2,
#                      'transitivity': 0,
#                      'tree_number': 1}},
#   'n_edges': 4,
#   'n_iterations': 2,
#   'n_nodes': 10,
#   'parameters': {'n': 10, 'p': 0.15}},
#  {'attribute_list': [],
#   'example_graph': <networkx.classes.graph.Graph object at 0x7f4de9f096d8>,
#   'graph_type': 'erdos_renyi_random_location',
#   'iterations': {0: {'min_weighted_vertex_cover_len': 8,
#                      'n_edges': 13,
#                      'n_maximal_cliques': 9,
#                      'n_triangles': 3.0,
#                      'node_connectivity': 1,
#                      'size_maximum_clique': 3,
#                      'transitivity': 0.2903225806451613,
#                      'tree_number': 3},
#                  1: {'min_weighted_vertex_cover_len': 8,
#                      'n_edges': 10,
#                      'n_maximal_cliques': 10,
#                      'n_triangles': 0.0,
#                      'node_connectivity': 0,
#                      'size_maximum_clique': 2,
#                      'transitivity': 0,
#                      'tree_number': 2}},
#   'n_edges': 13,
#   'n_iterations': 2,
#   'n_nodes': 10,
#   'parameters': {'n': 10, 'p': 0.2}},
#  {'attribute_list': [],
#   'example_graph': <networkx.classes.graph.Graph object at 0x7f4de9f09668>,
#   'graph_type': 'erdos_renyi_random_location',
#   'iterations': {0: {'min_weighted_vertex_cover_len': 8,
#                      'n_edges': 10,
#                      'n_maximal_cliques': 8,
#                      'n_triangles': 1.0,
#                      'node_connectivity': 1,
#                      'size_maximum_clique': 3,
#                      'transitivity': 0.2,
#                      'tree_number': 2},
#                  1: {'min_weighted_vertex_cover_len': 6,
#                      'n_edges': 11,
#                      'n_maximal_cliques': 9,
#                      'n_triangles': 1.0,
#                      'node_connectivity': 1,
#                      'size_maximum_clique': 3,
#                      'transitivity': 0.15789473684210525,
#                      'tree_number': 2}},
#   'n_edges': 10,
#   'n_iterations': 2,
#   'n_nodes': 10,
#   'parameters': {'n': 10, 'p': 0.25}}]

# %% [markdown]
# # Visualize Some of the Graphs

# %%
# %matplotlib inline

# %%
graph_1_name = "erdos_renyi_random_location:_n=10_p=0.20"
example_graph_1 = data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'erdos_renyi_random_location:_n=10_p=0.20')

# %%
graph_2_name = "erdos_renyi_random_location:_n=20_p=0.10"
example_graph_2 = data_structure[graph_2_name]["example_graph"]
fig = graph_network_matplotlib(example_graph_2,plot_type="2D",
                                            layout="collapse_x",
                                          colors="black",
                                         colors_edge = "green",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

# %%
fig = graph_network_matplotlib([example_graph_1,example_graph_2],plot_type="3D",
                                            layout="collapse_x",
                                          colors=["red","black"],
                                         colors_edge = ["blue","green"],
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

fig = graph_network_matplotlib([example_graph_1,example_graph_2],plot_type="2D",
                                            layout="collapse_z",
                                          colors=["red","black"],
                                         colors_edge = ["blue","green"],
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

# %% [markdown]
# # Specific Queries of Results of Experiment

# %%
df = table_comparison_statistics(data_structure)
index_restriction = ["n=50","p=0.25"]
column_restriction = ["transitivity","size_maximum_clique","n_triangles","graph_type"]
value_restriction = "transitivity > 0.1 AND size_maximum_clique < 12 OR n_triangles > 20"
returned_df = restrict_pandas(df,index_restriction,column_restriction,value_restriction)
returned_df
# Out:
#                                        graphs  transitivity  \
# 0    erdos_renyi_random_location:_n=10_p=0.25      0.178947
# 1    erdos_renyi_random_location:_n=20_p=0.25      0.214148
# 2    erdos_renyi_random_location:_n=50_p=0.10      0.107053
# 3    erdos_renyi_random_location:_n=50_p=0.15      0.136996
# 4    erdos_renyi_random_location:_n=50_p=0.20      0.198983
# 5    erdos_renyi_random_location:_n=50_p=0.25      0.251665
# 6    erdos_renyi_random_location:_n=50_p=0.30      0.275502
# 7    erdos_renyi_random_location:_n=50_p=0.35      0.342463
# 8    erdos_renyi_random_location:_n=50_p=0.40      0.395904
# 9   erdos_renyi_random_location:_n=100_p=0.25      0.261855
# 10  erdos_renyi_random_location:_n=150_p=0.25      0.249614
#
#     size_maximum_clique  n_triangles                   graph_type
# 0                   3.0          1.0  erdos_renyi_random_location
# 1                   3.5         16.0  erdos_renyi_random_location
# 2                   3.5         23.5  erdos_renyi_random_location
# 3                   3.5         55.0  erdos_renyi_random_location
# 4                   4.0        171.5  erdos_renyi_random_location
# 5                   5.0        320.0  erdos_renyi_random_location
# 6                   5.0        440.5  erdos_renyi_random_location
# 7                   6.0        785.0  erdos_renyi_random_location
# 8                   6.5       1258.0  erdos_renyi_random_location
# 9                   6.0       2816.5  erdos_renyi_random_location
# 10                  6.0       8519.5  erdos_renyi_random_location

# %%
returned_pandas = plot_df_values(df,index_restriction=[],
               x_column="n",
               y_column="n_edges",
               z_column = "n_triangles",
                    grouping=dict(p=dict(exact=[]),),
                   plot_type="scatter",
                   title=" Looking at triangles",
                  value_restriction="tree_number > 4 AND n_triangles > 4",
                                )

returned_pandas
# Out:
# returning figure and ax
#                                       graphs    n     p  n_triangles  \
# 0   erdos_renyi_random_location:_n=20_p=0.15   20  0.15          4.5
# 1   erdos_renyi_random_location:_n=50_p=0.15   50  0.15         55.0
# 2  erdos_renyi_random_location:_n=100_p=0.15  100  0.15        540.5
# 3  erdos_renyi_random_location:_n=150_p=0.15  150  0.15       1798.0
# 0   erdos_renyi_random_location:_n=20_p=0.25   20  0.25         16.0
# 1   erdos_renyi_random_location:_n=50_p=0.25   50  0.25        320.0
# 2  erdos_renyi_random_location:_n=100_p=0.25  100  0.25       2816.5
# 3  erdos_renyi_random_location:_n=150_p=0.25  150  0.25       8519.5
# 0   erdos_renyi_random_location:_n=20_p=0.35   20  0.35         48.5
# 1   erdos_renyi_random_location:_n=50_p=0.35   50  0.35        785.0
# 2  erdos_renyi_random_location:_n=100_p=0.35  100  0.35       6884.5
# 3  erdos_renyi_random_location:_n=150_p=0.35  150  0.35      22445.5
# 0   erdos_renyi_random_location:_n=20_p=0.30   20  0.30         30.0
# 1   erdos_renyi_random_location:_n=50_p=0.30   50  0.30        440.5
# 2  erdos_renyi_random_location:_n=100_p=0.30  100  0.30       4525.0
# 3  erdos_renyi_random_location:_n=150_p=0.30  150  0.30      15341.0
# 0   erdos_renyi_random_location:_n=20_p=0.40   20  0.40         88.5
# 1   erdos_renyi_random_location:_n=50_p=0.40   50  0.40       1258.0
# 2  erdos_renyi_random_location:_n=100_p=0.40  100  0.40      10269.0
# 3  erdos_renyi_random_location:_n=150_p=0.40  150  0.40      35026.0
# 0   erdos_renyi_random_location:_n=50_p=0.10   50  0.10         23.5
# 1  erdos_renyi_random_location:_n=100_p=0.10  100  0.10        162.0
# 2  erdos_renyi_random_location:_n=150_p=0.10  150  0.10        563.0
# 0   erdos_renyi_random_location:_n=50_p=0.20   50  0.20        171.5
# 1  erdos_renyi_random_location:_n=100_p=0.20  100  0.20       1346.0
# 2  erdos_renyi_random_location:_n=150_p=0.20  150  0.20       4419.5
# 0  erdos_renyi_random_location:_n=100_p=0.05  100  0.05         15.5
# 1  erdos_renyi_random_location:_n=150_p=0.05  150  0.05         74.5
#
#    transitivity  node_connectivity  size_maximum_clique  n_maximal_cliques  \
# 0      0.165555                1.0                  3.0               24.5
# 1      0.136996                2.0                  3.5              117.0
# 2      0.148579                6.5                  4.0              517.5
# 3      0.147812               12.0                  4.5             1372.0
# 0      0.214148                1.5                  3.5               30.0
# 1      0.251665                6.0                  5.0              212.0
# 2      0.261855               14.5                  6.0             1358.5
# 3      0.249614               25.0                  6.0             4062.5
# 0      0.380054                2.0                  4.5               35.0
# 1      0.342463                8.0                  6.0              351.5
# 2      0.349400               24.0                  7.0             3188.0
# 3      0.343569               39.5                  7.5            12349.5
# 0      0.292167                2.0                  4.0               32.5
# 1      0.275502                8.0                  5.0              248.5
# 2      0.302166               21.0                  6.0             2049.5
# 3      0.302904               33.0                  7.0             7616.0
# 0      0.440248                3.5                  4.5               43.0
# 1      0.395904               14.0                  6.5              498.0
# 2      0.399862               26.5                  8.0             5128.0
# 3      0.398644               46.0                  8.0            24849.5
# 0      0.107053                0.0                  3.5               93.0
# 1      0.102062                2.0                  4.0              323.0
# 2      0.101306                5.5                  4.0              749.0
# 0      0.198983                3.5                  4.0              173.5
# 1      0.203436               10.5                  5.0              860.5
# 2      0.200033               16.0                  5.0             2421.5
# 0      0.044502                0.0                  3.0              205.0
# 1      0.050298                1.5                  3.5              468.0
#
#    min_weighted_vertex_cover_len  tree_number  n_edges  \
# 0                           18.0          4.5       33
# 1                           44.0         20.5      165
# 2                           93.0         61.0      724
# 3                          146.0        103.5     1678
# 0                           17.0          6.5       53
# 1                           47.0         29.0      318
# 2                           97.0         74.0     1266
# 3                          146.0        120.5     2790
# 0                           17.0          8.5       62
# 1                           48.0         33.5      419
# 2                           97.0         79.0     1698
# 3                          148.0        127.5     3817
# 0                           19.0          8.5       60
# 1                           48.0         31.5      361
# 2                           97.0         78.0     1505
# 3                          149.0        125.5     3314
# 0                           18.0         10.5       80
# 1                           48.0         35.5      479
# 2                           97.0         81.0     1937
# 3                          148.0        130.5     4511
# 0                           45.0         14.5      121
# 1                           95.0         49.0      497
# 2                          142.0         91.0     1135
# 0                           47.0         25.5      258
# 1                           96.0         67.5     1014
# 2                          149.0        113.5     2251
# 0                           84.0         25.0      220
# 1                          134.0         59.5      566
#
#                     graph_type
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location

# %%
returned_pandas = plot_df_values(df,index_restriction=[],
               x_column="n_edges",
               y_column="n_triangles",
                    grouping=dict(p=dict(exact=[]),),
                   plot_type="line",
                   title=" Looking at triangles",
                  value_restriction="tree_number > 4 AND n_triangles > 4",
                                )
returned_pandas
# Out:
# returning figure and ax
#                                       graphs    n     p  n_triangles  \
# 0   erdos_renyi_random_location:_n=20_p=0.15   20  0.15          4.5
# 1   erdos_renyi_random_location:_n=50_p=0.15   50  0.15         55.0
# 2  erdos_renyi_random_location:_n=100_p=0.15  100  0.15        540.5
# 3  erdos_renyi_random_location:_n=150_p=0.15  150  0.15       1798.0
# 0   erdos_renyi_random_location:_n=20_p=0.25   20  0.25         16.0
# 1   erdos_renyi_random_location:_n=50_p=0.25   50  0.25        320.0
# 2  erdos_renyi_random_location:_n=100_p=0.25  100  0.25       2816.5
# 3  erdos_renyi_random_location:_n=150_p=0.25  150  0.25       8519.5
# 0   erdos_renyi_random_location:_n=20_p=0.35   20  0.35         48.5
# 1   erdos_renyi_random_location:_n=50_p=0.35   50  0.35        785.0
# 2  erdos_renyi_random_location:_n=100_p=0.35  100  0.35       6884.5
# 3  erdos_renyi_random_location:_n=150_p=0.35  150  0.35      22445.5
# 0   erdos_renyi_random_location:_n=20_p=0.30   20  0.30         30.0
# 1   erdos_renyi_random_location:_n=50_p=0.30   50  0.30        440.5
# 2  erdos_renyi_random_location:_n=100_p=0.30  100  0.30       4525.0
# 3  erdos_renyi_random_location:_n=150_p=0.30  150  0.30      15341.0
# 0   erdos_renyi_random_location:_n=20_p=0.40   20  0.40         88.5
# 1   erdos_renyi_random_location:_n=50_p=0.40   50  0.40       1258.0
# 2  erdos_renyi_random_location:_n=100_p=0.40  100  0.40      10269.0
# 3  erdos_renyi_random_location:_n=150_p=0.40  150  0.40      35026.0
# 0   erdos_renyi_random_location:_n=50_p=0.10   50  0.10         23.5
# 1  erdos_renyi_random_location:_n=100_p=0.10  100  0.10        162.0
# 2  erdos_renyi_random_location:_n=150_p=0.10  150  0.10        563.0
# 0   erdos_renyi_random_location:_n=50_p=0.20   50  0.20        171.5
# 1  erdos_renyi_random_location:_n=100_p=0.20  100  0.20       1346.0
# 2  erdos_renyi_random_location:_n=150_p=0.20  150  0.20       4419.5
# 0  erdos_renyi_random_location:_n=100_p=0.05  100  0.05         15.5
# 1  erdos_renyi_random_location:_n=150_p=0.05  150  0.05         74.5
#
#    transitivity  node_connectivity  size_maximum_clique  n_maximal_cliques  \
# 0      0.165555                1.0                  3.0               24.5
# 1      0.136996                2.0                  3.5              117.0
# 2      0.148579                6.5                  4.0              517.5
# 3      0.147812               12.0                  4.5             1372.0
# 0      0.214148                1.5                  3.5               30.0
# 1      0.251665                6.0                  5.0              212.0
# 2      0.261855               14.5                  6.0             1358.5
# 3      0.249614               25.0                  6.0             4062.5
# 0      0.380054                2.0                  4.5               35.0
# 1      0.342463                8.0                  6.0              351.5
# 2      0.349400               24.0                  7.0             3188.0
# 3      0.343569               39.5                  7.5            12349.5
# 0      0.292167                2.0                  4.0               32.5
# 1      0.275502                8.0                  5.0              248.5
# 2      0.302166               21.0                  6.0             2049.5
# 3      0.302904               33.0                  7.0             7616.0
# 0      0.440248                3.5                  4.5               43.0
# 1      0.395904               14.0                  6.5              498.0
# 2      0.399862               26.5                  8.0             5128.0
# 3      0.398644               46.0                  8.0            24849.5
# 0      0.107053                0.0                  3.5               93.0
# 1      0.102062                2.0                  4.0              323.0
# 2      0.101306                5.5                  4.0              749.0
# 0      0.198983                3.5                  4.0              173.5
# 1      0.203436               10.5                  5.0              860.5
# 2      0.200033               16.0                  5.0             2421.5
# 0      0.044502                0.0                  3.0              205.0
# 1      0.050298                1.5                  3.5              468.0
#
#    min_weighted_vertex_cover_len  tree_number  n_edges  \
# 0                           18.0          4.5       33
# 1                           44.0         20.5      165
# 2                           93.0         61.0      724
# 3                          146.0        103.5     1678
# 0                           17.0          6.5       53
# 1                           47.0         29.0      318
# 2                           97.0         74.0     1266
# 3                          146.0        120.5     2790
# 0                           17.0          8.5       62
# 1                           48.0         33.5      419
# 2                           97.0         79.0     1698
# 3                          148.0        127.5     3817
# 0                           19.0          8.5       60
# 1                           48.0         31.5      361
# 2                           97.0         78.0     1505
# 3                          149.0        125.5     3314
# 0                           18.0         10.5       80
# 1                           48.0         35.5      479
# 2                           97.0         81.0     1937
# 3                          148.0        130.5     4511
# 0                           45.0         14.5      121
# 1                           95.0         49.0      497
# 2                          142.0         91.0     1135
# 0                           47.0         25.5      258
# 1                           96.0         67.5     1014
# 2                          149.0        113.5     2251
# 0                           84.0         25.0      220
# 1                          134.0         59.5      566
#
#                     graph_type
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
