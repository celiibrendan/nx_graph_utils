# %%
import graph_experiments_utils as gu
# %matplotlib widget

# %% [markdown]
# # Run the Experiment

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = erdos_renyi_random_location

loop_1 = dict(n=[10,20,50,100,150])
loop_2 = dict(p=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4])
iterable_loops = [loop_1,loop_2]
n_iterations = 2


data_structure = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %%
data_structure
# Out:
# {'erdos_renyi_random_location:_n=10_p=0.05': {'iterations': {0: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 0,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 7,
#     'min_weighted_vertex_cover_len': 6,
#     'tree_number': 1,
#     'n_edges': 3},
#    1: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 0,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 8,
#     'min_weighted_vertex_cover_len': 4,
#     'tree_number': 1,
#     'n_edges': 2}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7e8d0>,
#   'n_nodes': 10,
#   'n_edges': 3,
#   'parameters': {'n': 10, 'p': 0.05}},
#  'erdos_renyi_random_location:_n=10_p=0.10': {'iterations': {0: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 0,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 8,
#     'min_weighted_vertex_cover_len': 4,
#     'tree_number': 1,
#     'n_edges': 3},
#    1: {'n_triangles': 1.0,
#     'transitivity': 0.375,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 8,
#     'min_weighted_vertex_cover_len': 2,
#     'tree_number': 2,
#     'n_edges': 5}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ea58>,
#   'n_nodes': 10,
#   'n_edges': 3,
#   'parameters': {'n': 10, 'p': 0.1}},
#  'erdos_renyi_random_location:_n=10_p=0.15': {'iterations': {0: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 0,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 8,
#     'min_weighted_vertex_cover_len': 4,
#     'tree_number': 1,
#     'n_edges': 3},
#    1: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 0,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 9,
#     'min_weighted_vertex_cover_len': 4,
#     'tree_number': 1,
#     'n_edges': 4}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eb00>,
#   'n_nodes': 10,
#   'n_edges': 3,
#   'parameters': {'n': 10, 'p': 0.15}},
#  'erdos_renyi_random_location:_n=10_p=0.20': {'iterations': {0: {'n_triangles': 1.0,
#     'transitivity': 0.17647058823529413,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 9,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 2,
#     'n_edges': 11},
#    1: {'n_triangles': 2.0,
#     'transitivity': 0.25,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 8,
#     'min_weighted_vertex_cover_len': 6,
#     'tree_number': 2,
#     'n_edges': 12}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eb38>,
#   'n_nodes': 10,
#   'n_edges': 11,
#   'parameters': {'n': 10, 'p': 0.2}},
#  'erdos_renyi_random_location:_n=10_p=0.25': {'iterations': {0: {'n_triangles': 1.0,
#     'transitivity': 0.16666666666666666,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 9,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 2,
#     'n_edges': 11},
#    1: {'n_triangles': 2.0,
#     'transitivity': 0.20689655172413793,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 10,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 3,
#     'n_edges': 14}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7e898>,
#   'n_nodes': 10,
#   'n_edges': 11,
#   'parameters': {'n': 10, 'p': 0.25}},
#  'erdos_renyi_random_location:_n=10_p=0.30': {'iterations': {0: {'n_triangles': 4.0,
#     'transitivity': 0.2608695652173913,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 10,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 4,
#     'n_edges': 16},
#    1: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 1,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 11,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 2,
#     'n_edges': 11}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eb70>,
#   'n_nodes': 10,
#   'n_edges': 16,
#   'parameters': {'n': 10, 'p': 0.3}},
#  'erdos_renyi_random_location:_n=10_p=0.35': {'iterations': {0: {'n_triangles': 6.0,
#     'transitivity': 0.4186046511627907,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 8,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 3,
#     'n_edges': 16},
#    1: {'n_triangles': 3.0,
#     'transitivity': 0.23684210526315788,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 11,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 3,
#     'n_edges': 15}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7e940>,
#   'n_nodes': 10,
#   'n_edges': 16,
#   'parameters': {'n': 10, 'p': 0.35}},
#  'erdos_renyi_random_location:_n=10_p=0.40': {'iterations': {0: {'n_triangles': 8.0,
#     'transitivity': 0.38095238095238093,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 10,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 4,
#     'n_edges': 19},
#    1: {'n_triangles': 16.0,
#     'transitivity': 0.5714285714285714,
#     'node_connectivity': 1,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 7,
#     'min_weighted_vertex_cover_len': 8,
#     'tree_number': 4,
#     'n_edges': 20}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eac8>,
#   'n_nodes': 10,
#   'n_edges': 19,
#   'parameters': {'n': 10, 'p': 0.4}},
#  'erdos_renyi_random_location:_n=20_p=0.05': {'iterations': {0: {'n_triangles': 1.0,
#     'transitivity': 0.25,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 16,
#     'min_weighted_vertex_cover_len': 10,
#     'tree_number': 2,
#     'n_edges': 10},
#    1: {'n_triangles': 0.0,
#     'transitivity': 0,
#     'node_connectivity': 0,
#     'size_maximum_clique': 2,
#     'n_maximal_cliques': 17,
#     'min_weighted_vertex_cover_len': 10,
#     'tree_number': 1,
#     'n_edges': 7}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eba8>,
#   'n_nodes': 20,
#   'n_edges': 10,
#   'parameters': {'n': 20, 'p': 0.05}},
#  'erdos_renyi_random_location:_n=20_p=0.10': {'iterations': {0: {'n_triangles': 3.0,
#     'transitivity': 0.2571428571428571,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 16,
#     'min_weighted_vertex_cover_len': 14,
#     'tree_number': 2,
#     'n_edges': 20},
#    1: {'n_triangles': 1.0,
#     'transitivity': 0.0967741935483871,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 18,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 2,
#     'n_edges': 19}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ebe0>,
#   'n_nodes': 20,
#   'n_edges': 20,
#   'parameters': {'n': 20, 'p': 0.1}},
#  'erdos_renyi_random_location:_n=20_p=0.15': {'iterations': {0: {'n_triangles': 3.0,
#     'transitivity': 0.14285714285714285,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 22,
#     'min_weighted_vertex_cover_len': 16,
#     'tree_number': 3,
#     'n_edges': 27},
#    1: {'n_triangles': 1.0,
#     'transitivity': 0.061224489795918366,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 24,
#     'min_weighted_vertex_cover_len': 14,
#     'tree_number': 4,
#     'n_edges': 24}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ec18>,
#   'n_nodes': 20,
#   'n_edges': 27,
#   'parameters': {'n': 20, 'p': 0.15}},
#  'erdos_renyi_random_location:_n=20_p=0.20': {'iterations': {0: {'n_triangles': 5.0,
#     'transitivity': 0.12931034482758622,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 28,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 5,
#     'n_edges': 34},
#    1: {'n_triangles': 8.0,
#     'transitivity': 0.21052631578947367,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 24,
#     'min_weighted_vertex_cover_len': 16,
#     'tree_number': 4,
#     'n_edges': 35}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ec50>,
#   'n_nodes': 20,
#   'n_edges': 34,
#   'parameters': {'n': 20, 'p': 0.2}},
#  'erdos_renyi_random_location:_n=20_p=0.25': {'iterations': {0: {'n_triangles': 17.0,
#     'transitivity': 0.204,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 35,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 7,
#     'n_edges': 51},
#    1: {'n_triangles': 16.0,
#     'transitivity': 0.2096069868995633,
#     'node_connectivity': 3,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 32,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 8,
#     'n_edges': 51}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ec88>,
#   'n_nodes': 20,
#   'n_edges': 51,
#   'parameters': {'n': 20, 'p': 0.25}},
#  'erdos_renyi_random_location:_n=20_p=0.30': {'iterations': {0: {'n_triangles': 22.0,
#     'transitivity': 0.23826714801444043,
#     'node_connectivity': 3,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 38,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 8,
#     'n_edges': 55},
#    1: {'n_triangles': 41.0,
#     'transitivity': 0.3297587131367292,
#     'node_connectivity': 1,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 31,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 10,
#     'n_edges': 63}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ecc0>,
#   'n_nodes': 20,
#   'n_edges': 55,
#   'parameters': {'n': 20, 'p': 0.3}},
#  'erdos_renyi_random_location:_n=20_p=0.35': {'iterations': {0: {'n_triangles': 80.0,
#     'transitivity': 0.4247787610619469,
#     'node_connectivity': 3,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 40,
#     'min_weighted_vertex_cover_len': 20,
#     'tree_number': 10,
#     'n_edges': 76},
#    1: {'n_triangles': 53.0,
#     'transitivity': 0.3646788990825688,
#     'node_connectivity': 3,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 36,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 10,
#     'n_edges': 68}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ecf8>,
#   'n_nodes': 20,
#   'n_edges': 76,
#   'parameters': {'n': 20, 'p': 0.35}},
#  'erdos_renyi_random_location:_n=20_p=0.40': {'iterations': {0: {'n_triangles': 66.0,
#     'transitivity': 0.3944223107569721,
#     'node_connectivity': 5,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 35,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 11,
#     'n_edges': 74},
#    1: {'n_triangles': 82.0,
#     'transitivity': 0.4155405405405405,
#     'node_connectivity': 4,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 42,
#     'min_weighted_vertex_cover_len': 18,
#     'tree_number': 10,
#     'n_edges': 79}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ed30>,
#   'n_nodes': 20,
#   'n_edges': 74,
#   'parameters': {'n': 20, 'p': 0.4}},
#  'erdos_renyi_random_location:_n=50_p=0.05': {'iterations': {0: {'n_triangles': 3.0,
#     'transitivity': 0.059602649006622516,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 63,
#     'min_weighted_vertex_cover_len': 42,
#     'tree_number': 5,
#     'n_edges': 67},
#    1: {'n_triangles': 6.0,
#     'transitivity': 0.06405693950177936,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 74,
#     'min_weighted_vertex_cover_len': 38,
#     'tree_number': 9,
#     'n_edges': 82}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ed68>,
#   'n_nodes': 50,
#   'n_edges': 67,
#   'parameters': {'n': 50, 'p': 0.05}},
#  'erdos_renyi_random_location:_n=50_p=0.10': {'iterations': {0: {'n_triangles': 26.0,
#     'transitivity': 0.11729323308270677,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 95,
#     'min_weighted_vertex_cover_len': 40,
#     'tree_number': 16,
#     'n_edges': 129},
#    1: {'n_triangles': 16.0,
#     'transitivity': 0.08465608465608465,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 99,
#     'min_weighted_vertex_cover_len': 42,
#     'tree_number': 14,
#     'n_edges': 123}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eda0>,
#   'n_nodes': 50,
#   'n_edges': 129,
#   'parameters': {'n': 50, 'p': 0.1}},
#  'erdos_renyi_random_location:_n=50_p=0.15': {'iterations': {0: {'n_triangles': 62.0,
#     'transitivity': 0.13025210084033614,
#     'node_connectivity': 2,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 127,
#     'min_weighted_vertex_cover_len': 44,
#     'tree_number': 25,
#     'n_edges': 194},
#    1: {'n_triangles': 56.0,
#     'transitivity': 0.14310051107325383,
#     'node_connectivity': 3,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 119,
#     'min_weighted_vertex_cover_len': 44,
#     'tree_number': 19,
#     'n_edges': 175}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7edd8>,
#   'n_nodes': 50,
#   'n_edges': 194,
#   'parameters': {'n': 50, 'p': 0.15}},
#  'erdos_renyi_random_location:_n=50_p=0.20': {'iterations': {0: {'n_triangles': 154.0,
#     'transitivity': 0.20388349514563106,
#     'node_connectivity': 4,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 153,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 28,
#     'n_edges': 244},
#    1: {'n_triangles': 168.0,
#     'transitivity': 0.20817843866171004,
#     'node_connectivity': 5,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 156,
#     'min_weighted_vertex_cover_len': 46,
#     'tree_number': 26,
#     'n_edges': 247}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ee10>,
#   'n_nodes': 50,
#   'n_edges': 244,
#   'parameters': {'n': 50, 'p': 0.2}},
#  'erdos_renyi_random_location:_n=50_p=0.25': {'iterations': {0: {'n_triangles': 332.0,
#     'transitivity': 0.2536933265410087,
#     'node_connectivity': 7,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 219,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 31,
#     'n_edges': 318},
#    1: {'n_triangles': 206.0,
#     'transitivity': 0.20215897939156036,
#     'node_connectivity': 6,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 187,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 27,
#     'n_edges': 277}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ee48>,
#   'n_nodes': 50,
#   'n_edges': 318,
#   'parameters': {'n': 50, 'p': 0.25}},
#  'erdos_renyi_random_location:_n=50_p=0.30': {'iterations': {0: {'n_triangles': 473.0,
#     'transitivity': 0.28115712304339213,
#     'node_connectivity': 7,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 270,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 31,
#     'n_edges': 359},
#    1: {'n_triangles': 541.0,
#     'transitivity': 0.2977981651376147,
#     'node_connectivity': 11,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 286,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 32,
#     'n_edges': 376}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ee80>,
#   'n_nodes': 50,
#   'n_edges': 359,
#   'parameters': {'n': 50, 'p': 0.3}},
#  'erdos_renyi_random_location:_n=50_p=0.35': {'iterations': {0: {'n_triangles': 937.0,
#     'transitivity': 0.36242908715832906,
#     'node_connectivity': 9,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 386,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 34,
#     'n_edges': 444},
#    1: {'n_triangles': 747.0,
#     'transitivity': 0.33770343580470163,
#     'node_connectivity': 10,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 313,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 33,
#     'n_edges': 413}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eeb8>,
#   'n_nodes': 50,
#   'n_edges': 444,
#   'parameters': {'n': 50, 'p': 0.35}},
#  'erdos_renyi_random_location:_n=50_p=0.40': {'iterations': {0: {'n_triangles': 1354.0,
#     'transitivity': 0.4090222535494915,
#     'node_connectivity': 13,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 541,
#     'min_weighted_vertex_cover_len': 50,
#     'tree_number': 35,
#     'n_edges': 505},
#    1: {'n_triangles': 1037.0,
#     'transitivity': 0.3775485436893204,
#     'node_connectivity': 10,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 408,
#     'min_weighted_vertex_cover_len': 48,
#     'tree_number': 36,
#     'n_edges': 458}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7eef0>,
#   'n_nodes': 50,
#   'n_edges': 505,
#   'parameters': {'n': 50, 'p': 0.4}},
#  'erdos_renyi_random_location:_n=100_p=0.05': {'iterations': {0: {'n_triangles': 15.0,
#     'transitivity': 0.0390625,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 221,
#     'min_weighted_vertex_cover_len': 90,
#     'tree_number': 27,
#     'n_edges': 242},
#    1: {'n_triangles': 20.0,
#     'transitivity': 0.04716981132075472,
#     'node_connectivity': 0,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 219,
#     'min_weighted_vertex_cover_len': 88,
#     'tree_number': 26,
#     'n_edges': 250}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ef28>,
#   'n_nodes': 100,
#   'n_edges': 242,
#   'parameters': {'n': 100, 'p': 0.05}},
#  'erdos_renyi_random_location:_n=100_p=0.10': {'iterations': {0: {'n_triangles': 137.0,
#     'transitivity': 0.09267192784667418,
#     'node_connectivity': 3,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 316,
#     'min_weighted_vertex_cover_len': 96,
#     'tree_number': 47,
#     'n_edges': 473},
#    1: {'n_triangles': 151.0,
#     'transitivity': 0.10051031728422453,
#     'node_connectivity': 4,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 337,
#     'min_weighted_vertex_cover_len': 92,
#     'tree_number': 47,
#     'n_edges': 478}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ef60>,
#   'n_nodes': 100,
#   'n_edges': 473,
#   'parameters': {'n': 100, 'p': 0.1}},
#  'erdos_renyi_random_location:_n=100_p=0.15': {'iterations': {0: {'n_triangles': 575.0,
#     'transitivity': 0.1556718707697861,
#     'node_connectivity': 4,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 528,
#     'min_weighted_vertex_cover_len': 94,
#     'tree_number': 61,
#     'n_edges': 746},
#    1: {'n_triangles': 575.0,
#     'transitivity': 0.15476404091153778,
#     'node_connectivity': 4,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 511,
#     'min_weighted_vertex_cover_len': 94,
#     'tree_number': 58,
#     'n_edges': 746}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7ef98>,
#   'n_nodes': 100,
#   'n_edges': 746,
#   'parameters': {'n': 100, 'p': 0.15}},
#  'erdos_renyi_random_location:_n=100_p=0.20': {'iterations': {0: {'n_triangles': 1238.0,
#     'transitivity': 0.1993558776167472,
#     'node_connectivity': 7,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 809,
#     'min_weighted_vertex_cover_len': 96,
#     'tree_number': 68,
#     'n_edges': 969},
#    1: {'n_triangles': 1525.0,
#     'transitivity': 0.21095587218149123,
#     'node_connectivity': 11,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 928,
#     'min_weighted_vertex_cover_len': 98,
#     'tree_number': 71,
#     'n_edges': 1049}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7efd0>,
#   'n_nodes': 100,
#   'n_edges': 969,
#   'parameters': {'n': 100, 'p': 0.2}},
#  'erdos_renyi_random_location:_n=100_p=0.25': {'iterations': {0: {'n_triangles': 2722.0,
#     'transitivity': 0.2539810898233391,
#     'node_connectivity': 16,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 1322,
#     'min_weighted_vertex_cover_len': 96,
#     'tree_number': 73,
#     'n_edges': 1277},
#    1: {'n_triangles': 2286.0,
#     'transitivity': 0.2387799867692629,
#     'node_connectivity': 15,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 1192,
#     'min_weighted_vertex_cover_len': 98,
#     'tree_number': 75,
#     'n_edges': 1205}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7e9e8>,
#   'n_nodes': 100,
#   'n_edges': 1277,
#   'parameters': {'n': 100, 'p': 0.25}},
#  'erdos_renyi_random_location:_n=100_p=0.30': {'iterations': {0: {'n_triangles': 4085.0,
#     'transitivity': 0.2940964722822174,
#     'node_connectivity': 18,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 1782,
#     'min_weighted_vertex_cover_len': 98,
#     'tree_number': 76,
#     'n_edges': 1449},
#    1: {'n_triangles': 4665.0,
#     'transitivity': 0.30363845436202297,
#     'node_connectivity': 21,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 2137,
#     'min_weighted_vertex_cover_len': 98,
#     'tree_number': 78,
#     'n_edges': 1527}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11b49080>,
#   'n_nodes': 100,
#   'n_edges': 1449,
#   'parameters': {'n': 100, 'p': 0.3}},
#  'erdos_renyi_random_location:_n=100_p=0.35': {'iterations': {0: {'n_triangles': 6923.0,
#     'transitivity': 0.34607501707963273,
#     'node_connectivity': 25,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 3291,
#     'min_weighted_vertex_cover_len': 100,
#     'tree_number': 78,
#     'n_edges': 1744},
#    1: {'n_triangles': 7792.0,
#     'transitivity': 0.3652956619577447,
#     'node_connectivity': 23,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 3612,
#     'min_weighted_vertex_cover_len': 96,
#     'tree_number': 80,
#     'n_edges': 1793}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11b490b8>,
#   'n_nodes': 100,
#   'n_edges': 1744,
#   'parameters': {'n': 100, 'p': 0.35}},
#  'erdos_renyi_random_location:_n=100_p=0.40': {'iterations': {0: {'n_triangles': 11443.0,
#     'transitivity': 0.41489207415822676,
#     'node_connectivity': 26,
#     'size_maximum_clique': 8,
#     'n_maximal_cliques': 6066,
#     'min_weighted_vertex_cover_len': 98,
#     'tree_number': 83,
#     'n_edges': 2044},
#    1: {'n_triangles': 10825.0,
#     'transitivity': 0.406399779749465,
#     'node_connectivity': 27,
#     'size_maximum_clique': 8,
#     'n_maximal_cliques': 5470,
#     'min_weighted_vertex_cover_len': 100,
#     'tree_number': 82,
#     'n_edges': 2009}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f4529d668>,
#   'n_nodes': 100,
#   'n_edges': 2044,
#   'parameters': {'n': 100, 'p': 0.4}},
#  'erdos_renyi_random_location:_n=150_p=0.05': {'iterations': {0: {'n_triangles': 66.0,
#     'transitivity': 0.046078659529904586,
#     'node_connectivity': 2,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 467,
#     'min_weighted_vertex_cover_len': 136,
#     'tree_number': 59,
#     'n_edges': 570},
#    1: {'n_triangles': 69.0,
#     'transitivity': 0.04866008462623413,
#     'node_connectivity': 1,
#     'size_maximum_clique': 3,
#     'n_maximal_cliques': 469,
#     'min_weighted_vertex_cover_len': 138,
#     'tree_number': 61,
#     'n_edges': 567}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f12214eb8>,
#   'n_nodes': 150,
#   'n_edges': 570,
#   'parameters': {'n': 150, 'p': 0.05}},
#  'erdos_renyi_random_location:_n=150_p=0.10': {'iterations': {0: {'n_triangles': 508.0,
#     'transitivity': 0.09731179362748228,
#     'node_connectivity': 4,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 709,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 90,
#     'n_edges': 1091},
#    1: {'n_triangles': 484.0,
#     'transitivity': 0.09022556390977443,
#     'node_connectivity': 8,
#     'size_maximum_clique': 4,
#     'n_maximal_cliques': 757,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 90,
#     'n_edges': 1105}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f449dfac8>,
#   'n_nodes': 150,
#   'n_edges': 1091,
#   'parameters': {'n': 150, 'p': 0.1}},
#  'erdos_renyi_random_location:_n=150_p=0.15': {'iterations': {0: {'n_triangles': 1804.0,
#     'transitivity': 0.1488817364034002,
#     'node_connectivity': 14,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 1388,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 105,
#     'n_edges': 1664},
#    1: {'n_triangles': 1798.0,
#     'transitivity': 0.14848459823271948,
#     'node_connectivity': 11,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 1366,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 107,
#     'n_edges': 1660}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f122289b0>,
#   'n_nodes': 150,
#   'n_edges': 1664,
#   'parameters': {'n': 150, 'p': 0.15}},
#  'erdos_renyi_random_location:_n=150_p=0.20': {'iterations': {0: {'n_triangles': 4455.0,
#     'transitivity': 0.2000089790787465,
#     'node_connectivity': 19,
#     'size_maximum_clique': 5,
#     'n_maximal_cliques': 2529,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 112,
#     'n_edges': 2245},
#    1: {'n_triangles': 5062.0,
#     'transitivity': 0.2099688904251642,
#     'node_connectivity': 20,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 2623,
#     'min_weighted_vertex_cover_len': 148,
#     'tree_number': 115,
#     'n_edges': 2339}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f45ba8128>,
#   'n_nodes': 150,
#   'n_edges': 2245,
#   'parameters': {'n': 150, 'p': 0.2}},
#  'erdos_renyi_random_location:_n=150_p=0.25': {'iterations': {0: {'n_triangles': 8644.0,
#     'transitivity': 0.25032096143636273,
#     'node_connectivity': 23,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 4230,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 121,
#     'n_edges': 2797},
#    1: {'n_triangles': 8797.0,
#     'transitivity': 0.25143385225129095,
#     'node_connectivity': 25,
#     'size_maximum_clique': 6,
#     'n_maximal_cliques': 4205,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 115,
#     'n_edges': 2812}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11d7e978>,
#   'n_nodes': 150,
#   'n_edges': 2797,
#   'parameters': {'n': 150, 'p': 0.25}},
#  'erdos_renyi_random_location:_n=150_p=0.30': {'iterations': {0: {'n_triangles': 14639.0,
#     'transitivity': 0.2981061634537062,
#     'node_connectivity': 31,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 7231,
#     'min_weighted_vertex_cover_len': 146,
#     'tree_number': 124,
#     'n_edges': 3338},
#    1: {'n_triangles': 14906.0,
#     'transitivity': 0.2980107293992203,
#     'node_connectivity': 34,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 7469,
#     'min_weighted_vertex_cover_len': 148,
#     'tree_number': 124,
#     'n_edges': 3371}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11b490f0>,
#   'n_nodes': 150,
#   'n_edges': 3338,
#   'parameters': {'n': 150, 'p': 0.3}},
#  'erdos_renyi_random_location:_n=150_p=0.35': {'iterations': {0: {'n_triangles': 22164.0,
#     'transitivity': 0.3438802635525812,
#     'node_connectivity': 34,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 12187,
#     'min_weighted_vertex_cover_len': 150,
#     'tree_number': 130,
#     'n_edges': 3819},
#    1: {'n_triangles': 23574.0,
#     'transitivity': 0.34858686329984917,
#     'node_connectivity': 39,
#     'size_maximum_clique': 7,
#     'n_maximal_cliques': 13533,
#     'min_weighted_vertex_cover_len': 148,
#     'tree_number': 129,
#     'n_edges': 3913}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11b49128>,
#   'n_nodes': 150,
#   'n_edges': 3819,
#   'parameters': {'n': 150, 'p': 0.35}},
#  'erdos_renyi_random_location:_n=150_p=0.40': {'iterations': {0: {'n_triangles': 35778.0,
#     'transitivity': 0.4013971525910524,
#     'node_connectivity': 49,
#     'size_maximum_clique': 8,
#     'n_maximal_cliques': 25736,
#     'min_weighted_vertex_cover_len': 150,
#     'tree_number': 130,
#     'n_edges': 4497},
#    1: {'n_triangles': 35589.0,
#     'transitivity': 0.3996189720479691,
#     'node_connectivity': 48,
#     'size_maximum_clique': 8,
#     'n_maximal_cliques': 25395,
#     'min_weighted_vertex_cover_len': 150,
#     'tree_number': 130,
#     'n_edges': 4495}},
#   'n_iterations': 2,
#   'attribute_list': [],
#   'graph_type': 'erdos_renyi_random_location',
#   'example_graph': <networkx.classes.graph.Graph at 0x7f9f11b491d0>,
#   'n_nodes': 150,
#   'n_edges': 4497,
#   'parameters': {'n': 150, 'p': 0.4}}}

# %% [markdown]
# # Visualize Some of the Graphs

# %%
# %matplotlib widget

# %%
graph_1_name = "erdos_renyi_random_location:_n=10_p=0.20"
example_graph_1 = data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 0.92, 'erdos_renyi_random_location:_n=10_p=0.20')

# %%
graph_2_name = "erdos_renyi_random_location:_n=20_p=0.10"
example_graph_2 = data_structure[graph_2_name]["example_graph"]
fig = graph_network_matplotlib(example_graph_2,plot_type="2D",
                                            layout="collapse_x",
                                          colors="black",
                                         colors_edge = "green",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = graph_network_matplotlib([example_graph_1,example_graph_2],plot_type="3D",
                                            layout="collapse_x",
                                          colors=["red","black"],
                                         colors_edge = ["blue","green"],
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

fig = graph_network_matplotlib([example_graph_1,example_graph_2],plot_type="2D",
                                            layout="collapse_z",
                                          colors=["red","black"],
                                         colors_edge = ["blue","green"],
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Specific Queries of Results of Experiment

# %%
df = table_comparison_statistics(data_structure)
index_restriction = ["n=50","p=0.25"]
column_restriction = ["transitivity","size_maximum_clique","n_triangles","graph_type"]
value_restriction = "transitivity > 0.1 AND size_maximum_clique < 12 OR n_triangles > 20"
returned_df = restrict_pandas(df,index_restriction,column_restriction,value_restriction)
returned_df
# Out:
#                                        graphs  transitivity  \
# 0    erdos_renyi_random_location:_n=10_p=0.25      0.186782
# 1    erdos_renyi_random_location:_n=20_p=0.25      0.206803
# 2    erdos_renyi_random_location:_n=50_p=0.10      0.100975
# 3    erdos_renyi_random_location:_n=50_p=0.15      0.136676
# 4    erdos_renyi_random_location:_n=50_p=0.20      0.206031
# 5    erdos_renyi_random_location:_n=50_p=0.25      0.227926
# 6    erdos_renyi_random_location:_n=50_p=0.30      0.289478
# 7    erdos_renyi_random_location:_n=50_p=0.35      0.350066
# 8    erdos_renyi_random_location:_n=50_p=0.40      0.393285
# 9   erdos_renyi_random_location:_n=100_p=0.25      0.246381
# 10  erdos_renyi_random_location:_n=150_p=0.25      0.250877
#
#     size_maximum_clique  n_triangles                   graph_type
# 0                   3.0          1.5  erdos_renyi_random_location
# 1                   3.5         16.5  erdos_renyi_random_location
# 2                   3.0         21.0  erdos_renyi_random_location
# 3                   4.0         59.0  erdos_renyi_random_location
# 4                   4.0        161.0  erdos_renyi_random_location
# 5                   4.5        269.0  erdos_renyi_random_location
# 6                   5.0        507.0  erdos_renyi_random_location
# 7                   5.5        842.0  erdos_renyi_random_location
# 8                   6.5       1195.5  erdos_renyi_random_location
# 9                   5.5       2504.0  erdos_renyi_random_location
# 10                  6.0       8720.5  erdos_renyi_random_location

# %%
returned_pandas = plot_df_values(df,index_restriction=[],
               x_column="n",
               y_column="n_edges",
               z_column = "n_triangles",
                    grouping=dict(p=dict(exact=[]),),
                   plot_type="scatter",
                   title=" Looking at triangles",
                  value_restriction="tree_number > 4 AND n_triangles > 4",
                                )

returned_pandas
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# returning figure and ax
#                                       graphs    n     p  n_triangles  \
# 0   erdos_renyi_random_location:_n=20_p=0.20   20  0.20          6.5
# 1   erdos_renyi_random_location:_n=50_p=0.20   50  0.20        161.0
# 2  erdos_renyi_random_location:_n=100_p=0.20  100  0.20       1381.5
# 3  erdos_renyi_random_location:_n=150_p=0.20  150  0.20       4758.5
# 0   erdos_renyi_random_location:_n=20_p=0.25   20  0.25         16.5
# 1   erdos_renyi_random_location:_n=50_p=0.25   50  0.25        269.0
# 2  erdos_renyi_random_location:_n=100_p=0.25  100  0.25       2504.0
# 3  erdos_renyi_random_location:_n=150_p=0.25  150  0.25       8720.5
# 0   erdos_renyi_random_location:_n=20_p=0.35   20  0.35         66.5
# 1   erdos_renyi_random_location:_n=50_p=0.35   50  0.35        842.0
# 2  erdos_renyi_random_location:_n=100_p=0.35  100  0.35       7357.5
# 3  erdos_renyi_random_location:_n=150_p=0.35  150  0.35      22869.0
# 0   erdos_renyi_random_location:_n=20_p=0.30   20  0.30         31.5
# 1   erdos_renyi_random_location:_n=50_p=0.30   50  0.30        507.0
# 2  erdos_renyi_random_location:_n=100_p=0.30  100  0.30       4375.0
# 3  erdos_renyi_random_location:_n=150_p=0.30  150  0.30      14772.5
# 0   erdos_renyi_random_location:_n=20_p=0.40   20  0.40         74.0
# 1   erdos_renyi_random_location:_n=50_p=0.40   50  0.40       1195.5
# 2  erdos_renyi_random_location:_n=100_p=0.40  100  0.40      11134.0
# 3  erdos_renyi_random_location:_n=150_p=0.40  150  0.40      35683.5
# 0   erdos_renyi_random_location:_n=50_p=0.05   50  0.05          4.5
# 1  erdos_renyi_random_location:_n=100_p=0.05  100  0.05         17.5
# 2  erdos_renyi_random_location:_n=150_p=0.05  150  0.05         67.5
# 0   erdos_renyi_random_location:_n=50_p=0.10   50  0.10         21.0
# 1  erdos_renyi_random_location:_n=100_p=0.10  100  0.10        144.0
# 2  erdos_renyi_random_location:_n=150_p=0.10  150  0.10        496.0
# 0   erdos_renyi_random_location:_n=50_p=0.15   50  0.15         59.0
# 1  erdos_renyi_random_location:_n=100_p=0.15  100  0.15        575.0
# 2  erdos_renyi_random_location:_n=150_p=0.15  150  0.15       1801.0
#
#    transitivity  node_connectivity  size_maximum_clique  n_maximal_cliques  \
# 0      0.169918                0.0                  3.0               26.0
# 1      0.206031                4.5                  4.0              154.5
# 2      0.205156                9.0                  5.0              868.5
# 3      0.204989               19.5                  5.5             2576.0
# 0      0.206803                2.0                  3.5               33.5
# 1      0.227926                6.5                  4.5              203.0
# 2      0.246381               15.5                  5.5             1257.0
# 3      0.250877               24.0                  6.0             4217.5
# 0      0.394729                3.0                  4.5               38.0
# 1      0.350066                9.5                  5.5              349.5
# 2      0.355685               24.0                  7.0             3451.5
# 3      0.346234               36.5                  7.0            12860.0
# 0      0.284013                2.0                  4.0               34.5
# 1      0.289478                9.0                  5.0              278.0
# 2      0.298867               19.5                  6.0             1959.5
# 3      0.298058               32.5                  7.0             7350.0
# 0      0.404981                4.5                  5.0               38.5
# 1      0.393285               11.5                  6.5              474.5
# 2      0.410646               26.5                  8.0             5768.0
# 3      0.400508               48.5                  8.0            25565.5
# 0      0.061830                0.0                  3.0               68.5
# 1      0.043116                0.0                  3.0              220.0
# 2      0.047369                1.5                  3.0              468.0
# 0      0.100975                0.5                  3.0               97.0
# 1      0.096591                3.5                  4.0              326.5
# 2      0.093769                6.0                  4.0              733.0
# 0      0.136676                2.5                  4.0              123.0
# 1      0.155218                4.0                  4.5              519.5
# 2      0.148683               12.5                  5.0             1377.0
#
#    min_weighted_vertex_cover_len  tree_number  n_edges  \
# 0                           17.0          4.5       34
# 1                           47.0         27.0      244
# 2                           97.0         69.5      969
# 3                          147.0        113.5     2245
# 0                           18.0          7.5       51
# 1                           48.0         29.0      318
# 2                           97.0         74.0     1277
# 3                          146.0        118.0     2797
# 0                           19.0         10.0       76
# 1                           48.0         33.5      444
# 2                           98.0         79.0     1744
# 3                          149.0        129.5     3819
# 0                           18.0          9.0       55
# 1                           48.0         31.5      359
# 2                           98.0         77.0     1449
# 3                          147.0        124.0     3338
# 0                           18.0         10.5       74
# 1                           49.0         35.5      505
# 2                           99.0         82.5     2044
# 3                          150.0        130.0     4497
# 0                           40.0          7.0       67
# 1                           89.0         26.5      242
# 2                          137.0         60.0      570
# 0                           41.0         15.0      129
# 1                           94.0         47.0      473
# 2                          146.0         90.0     1091
# 0                           44.0         22.0      194
# 1                           94.0         59.5      746
# 2                          146.0        106.0     1664
#
#                     graph_type
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location

# %%
returned_pandas = plot_df_values(df,index_restriction=[],
               x_column="n_edges",
               y_column="n_triangles",
                    grouping=dict(p=dict(exact=[]),),
                   plot_type="line",
                   title=" Looking at triangles",
                  value_restriction="tree_number > 4 AND n_triangles > 4",
                                )
returned_pandas
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# returning figure and ax
#                                       graphs    n     p  n_triangles  \
# 0   erdos_renyi_random_location:_n=20_p=0.20   20  0.20          6.5
# 1   erdos_renyi_random_location:_n=50_p=0.20   50  0.20        161.0
# 2  erdos_renyi_random_location:_n=100_p=0.20  100  0.20       1381.5
# 3  erdos_renyi_random_location:_n=150_p=0.20  150  0.20       4758.5
# 0   erdos_renyi_random_location:_n=20_p=0.25   20  0.25         16.5
# 1   erdos_renyi_random_location:_n=50_p=0.25   50  0.25        269.0
# 2  erdos_renyi_random_location:_n=100_p=0.25  100  0.25       2504.0
# 3  erdos_renyi_random_location:_n=150_p=0.25  150  0.25       8720.5
# 0   erdos_renyi_random_location:_n=20_p=0.35   20  0.35         66.5
# 1   erdos_renyi_random_location:_n=50_p=0.35   50  0.35        842.0
# 2  erdos_renyi_random_location:_n=100_p=0.35  100  0.35       7357.5
# 3  erdos_renyi_random_location:_n=150_p=0.35  150  0.35      22869.0
# 0   erdos_renyi_random_location:_n=20_p=0.30   20  0.30         31.5
# 1   erdos_renyi_random_location:_n=50_p=0.30   50  0.30        507.0
# 2  erdos_renyi_random_location:_n=100_p=0.30  100  0.30       4375.0
# 3  erdos_renyi_random_location:_n=150_p=0.30  150  0.30      14772.5
# 0   erdos_renyi_random_location:_n=20_p=0.40   20  0.40         74.0
# 1   erdos_renyi_random_location:_n=50_p=0.40   50  0.40       1195.5
# 2  erdos_renyi_random_location:_n=100_p=0.40  100  0.40      11134.0
# 3  erdos_renyi_random_location:_n=150_p=0.40  150  0.40      35683.5
# 0   erdos_renyi_random_location:_n=50_p=0.05   50  0.05          4.5
# 1  erdos_renyi_random_location:_n=100_p=0.05  100  0.05         17.5
# 2  erdos_renyi_random_location:_n=150_p=0.05  150  0.05         67.5
# 0   erdos_renyi_random_location:_n=50_p=0.10   50  0.10         21.0
# 1  erdos_renyi_random_location:_n=100_p=0.10  100  0.10        144.0
# 2  erdos_renyi_random_location:_n=150_p=0.10  150  0.10        496.0
# 0   erdos_renyi_random_location:_n=50_p=0.15   50  0.15         59.0
# 1  erdos_renyi_random_location:_n=100_p=0.15  100  0.15        575.0
# 2  erdos_renyi_random_location:_n=150_p=0.15  150  0.15       1801.0
#
#    transitivity  node_connectivity  size_maximum_clique  n_maximal_cliques  \
# 0      0.169918                0.0                  3.0               26.0
# 1      0.206031                4.5                  4.0              154.5
# 2      0.205156                9.0                  5.0              868.5
# 3      0.204989               19.5                  5.5             2576.0
# 0      0.206803                2.0                  3.5               33.5
# 1      0.227926                6.5                  4.5              203.0
# 2      0.246381               15.5                  5.5             1257.0
# 3      0.250877               24.0                  6.0             4217.5
# 0      0.394729                3.0                  4.5               38.0
# 1      0.350066                9.5                  5.5              349.5
# 2      0.355685               24.0                  7.0             3451.5
# 3      0.346234               36.5                  7.0            12860.0
# 0      0.284013                2.0                  4.0               34.5
# 1      0.289478                9.0                  5.0              278.0
# 2      0.298867               19.5                  6.0             1959.5
# 3      0.298058               32.5                  7.0             7350.0
# 0      0.404981                4.5                  5.0               38.5
# 1      0.393285               11.5                  6.5              474.5
# 2      0.410646               26.5                  8.0             5768.0
# 3      0.400508               48.5                  8.0            25565.5
# 0      0.061830                0.0                  3.0               68.5
# 1      0.043116                0.0                  3.0              220.0
# 2      0.047369                1.5                  3.0              468.0
# 0      0.100975                0.5                  3.0               97.0
# 1      0.096591                3.5                  4.0              326.5
# 2      0.093769                6.0                  4.0              733.0
# 0      0.136676                2.5                  4.0              123.0
# 1      0.155218                4.0                  4.5              519.5
# 2      0.148683               12.5                  5.0             1377.0
#
#    min_weighted_vertex_cover_len  tree_number  n_edges  \
# 0                           17.0          4.5       34
# 1                           47.0         27.0      244
# 2                           97.0         69.5      969
# 3                          147.0        113.5     2245
# 0                           18.0          7.5       51
# 1                           48.0         29.0      318
# 2                           97.0         74.0     1277
# 3                          146.0        118.0     2797
# 0                           19.0         10.0       76
# 1                           48.0         33.5      444
# 2                           98.0         79.0     1744
# 3                          149.0        129.5     3819
# 0                           18.0          9.0       55
# 1                           48.0         31.5      359
# 2                           98.0         77.0     1449
# 3                          147.0        124.0     3338
# 0                           18.0         10.5       74
# 1                           49.0         35.5      505
# 2                           99.0         82.5     2044
# 3                          150.0        130.0     4497
# 0                           40.0          7.0       67
# 1                           89.0         26.5      242
# 2                          137.0         60.0      570
# 0                           41.0         15.0      129
# 1                           94.0         47.0      473
# 2                          146.0         90.0     1091
# 0                           44.0         22.0      194
# 1                           94.0         59.5      746
# 2                          146.0        106.0     1664
#
#                     graph_type
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 3  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
# 0  erdos_renyi_random_location
# 1  erdos_renyi_random_location
# 2  erdos_renyi_random_location
