# %%
import networkx as nx
import graph_experiments_utils as gu
# %matplotlib inline

# %% [markdown]
# # Available Graphs

# %%
#graph options
gu.watts_strogatz_graph_smallworld_random_location
gu.random_tree_random_location
gu.erdos_renyi_random_location
# Out:
# <function graph_experiments_utils.erdos_renyi_random_location(n, p)>

# %% [markdown]
# # Run the experiment

# %%
from graph_experiments_utils import *

# %%
functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = erdos_renyi_random_location

loop_1 = dict(n=[10,20,50,100,150])
loop_2 = dict(p=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4])
iterable_loops = [loop_1,loop_2]
n_iterations = 5


data_structure_erdos = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = random_tree_random_location

loop_1 = dict(n=[10,15,20,20,40,50,60,80,100,120,150,200])
iterable_loops = [loop_1]
n_iterations = 5


data_structure_tree = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = watts_strogatz_graph_smallworld_random_location

loop_1 = dict(n=[10,20,50,100,150])
loop_2 = dict(p=[0.1,0.4,0.6])
loop_3 = dict(k=[2,4,8])
iterable_loops = [loop_1,loop_2,loop_3]
n_iterations = 5


data_structure_smallworld = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

# %% [markdown]
# # Visualize some of the graphs

# %%
data_structure_erdos.keys()
# Out:
# dict_keys(['erdos_renyi_random_location:_n=10_p=0.05', 'erdos_renyi_random_location:_n=10_p=0.10', 'erdos_renyi_random_location:_n=10_p=0.15', 'erdos_renyi_random_location:_n=10_p=0.20', 'erdos_renyi_random_location:_n=10_p=0.25', 'erdos_renyi_random_location:_n=10_p=0.30', 'erdos_renyi_random_location:_n=10_p=0.35', 'erdos_renyi_random_location:_n=10_p=0.40', 'erdos_renyi_random_location:_n=20_p=0.05', 'erdos_renyi_random_location:_n=20_p=0.10', 'erdos_renyi_random_location:_n=20_p=0.15', 'erdos_renyi_random_location:_n=20_p=0.20', 'erdos_renyi_random_location:_n=20_p=0.25', 'erdos_renyi_random_location:_n=20_p=0.30', 'erdos_renyi_random_location:_n=20_p=0.35', 'erdos_renyi_random_location:_n=20_p=0.40', 'erdos_renyi_random_location:_n=50_p=0.05', 'erdos_renyi_random_location:_n=50_p=0.10', 'erdos_renyi_random_location:_n=50_p=0.15', 'erdos_renyi_random_location:_n=50_p=0.20', 'erdos_renyi_random_location:_n=50_p=0.25', 'erdos_renyi_random_location:_n=50_p=0.30', 'erdos_renyi_random_location:_n=50_p=0.35', 'erdos_renyi_random_location:_n=50_p=0.40', 'erdos_renyi_random_location:_n=100_p=0.05', 'erdos_renyi_random_location:_n=100_p=0.10', 'erdos_renyi_random_location:_n=100_p=0.15', 'erdos_renyi_random_location:_n=100_p=0.20', 'erdos_renyi_random_location:_n=100_p=0.25', 'erdos_renyi_random_location:_n=100_p=0.30', 'erdos_renyi_random_location:_n=100_p=0.35', 'erdos_renyi_random_location:_n=100_p=0.40', 'erdos_renyi_random_location:_n=150_p=0.05', 'erdos_renyi_random_location:_n=150_p=0.10', 'erdos_renyi_random_location:_n=150_p=0.15', 'erdos_renyi_random_location:_n=150_p=0.20', 'erdos_renyi_random_location:_n=150_p=0.25', 'erdos_renyi_random_location:_n=150_p=0.30', 'erdos_renyi_random_location:_n=150_p=0.35', 'erdos_renyi_random_location:_n=150_p=0.40'])

# %%
current_data_structure = data_structure_erdos

graph_1_name = list(current_data_structure.keys())[13]
example_graph_1 = current_data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'erdos_renyi_random_location:_n=20_p=0.30')

# %%
current_data_structure = data_structure_tree

graph_1_name = list(current_data_structure.keys())[2]
example_graph_1 = current_data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'random_tree_random_location:_n=20')

# %%
current_data_structure = data_structure_smallworld

graph_1_name = list(current_data_structure.keys())[10]
example_graph_1 = current_data_structure[graph_1_name]["example_graph"]

fig = graph_network_matplotlib(example_graph_1,plot_type="3D",
                                            layout="locations",
                                          colors="red",
                                         colors_edge = "blue",
                                            node_size = 64,
                                       node_label_size=10,
                                       return_fig=True)

plt.title(graph_1_name)
# Out:
# Text(0.5, 0.92, 'watts_strogatz_graph_smallworld_random_location:_n=20_p=0.10_k=4')

# %% [markdown]
# # Compare Graph Statistics

# %%
data_structure_total = dict()
dict_to_combine = [data_structure_erdos,data_structure_smallworld,data_structure_tree,]
for dk in dict_to_combine:
    data_structure_total.update(dk)
df = table_comparison_statistics(data_structure_total)

# %%
df
# Out:
#                                       graphs    n   k     p  n_nodes  n_edges  \
# 0   erdos_renyi_random_location:_n=10_p=0.05   10 NaN  0.05       10        3
# 1   erdos_renyi_random_location:_n=10_p=0.10   10 NaN  0.10       10        3
# 2   erdos_renyi_random_location:_n=10_p=0.15   10 NaN  0.15       10       10
# 3   erdos_renyi_random_location:_n=10_p=0.20   10 NaN  0.20       10        8
# 4   erdos_renyi_random_location:_n=10_p=0.25   10 NaN  0.25       10       12
# ..                                       ...  ...  ..   ...      ...      ...
# 91         random_tree_random_location:_n=80   80 NaN   NaN       80       79
# 92        random_tree_random_location:_n=100  100 NaN   NaN      100       99
# 93        random_tree_random_location:_n=120  120 NaN   NaN      120      119
# 94        random_tree_random_location:_n=150  150 NaN   NaN      150      149
# 95        random_tree_random_location:_n=200  200 NaN   NaN      200      199
#
#     n_triangles  transitivity  node_connectivity  size_maximum_clique  \
# 0           0.0      0.000000                0.0                  1.8
# 1           0.0      0.000000                0.0                  2.0
# 2           0.4      0.054545                0.0                  2.2
# 3           1.2      0.216234                0.0                  2.6
# 4           1.8      0.221688                0.0                  2.8
# ..          ...           ...                ...                  ...
# 91          0.0      0.000000                1.0                  2.0
# 92          0.0      0.000000                1.0                  2.0
# 93          0.0      0.000000                1.0                  2.0
# 94          0.0      0.000000                1.0                  2.0
# 95          0.0      0.000000                1.0                  2.0
#
#     n_maximal_cliques  min_weighted_vertex_cover_len  tree_number  \
# 0                 8.8                            3.2          0.8
# 1                 8.4                            4.8          1.0
# 2                 8.4                            6.0          1.4
# 3                 8.4                            5.6          1.6
# 4                 8.6                            7.6          2.2
# ..                ...                            ...          ...
# 91               79.0                           64.4          1.0
# 92               99.0                           81.6          1.0
# 93              119.0                           97.6          1.0
# 94              149.0                          121.2          1.0
# 95              199.0                          160.4          1.0
#
#                      graph_type
# 0   erdos_renyi_random_location
# 1   erdos_renyi_random_location
# 2   erdos_renyi_random_location
# 3   erdos_renyi_random_location
# 4   erdos_renyi_random_location
# ..                          ...
# 91  random_tree_random_location
# 92  random_tree_random_location
# 93  random_tree_random_location
# 94  random_tree_random_location
# 95  random_tree_random_location
#
# [96 rows x 14 columns]

# %%
from importlib import reload  # Python 3.4+ only.
import graph_experiments_utils
graph_experiments_utils = reload(graph_experiments_utils)

# %%
returned_df, (fig,ax) = graph_experiments_utils.plot_df_values(df,index_restriction=[],
               x_column="n_edges",
               y_column = "n",
               z_column = "n_triangles",
                grouping=dict(graph_type=dict(exact=[])),
               plot_type="scatter",
               title="Triangles vs. Node Count,Edge_Count",
              #value_restriction=" n_edges > 10 ",
                return_fig_ax=True,
                return_plotted_df_table=True
                                )
# Update the plot
plt.show()
# Out:
# returning figure and ax

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

filtered_df  = restrict_pandas(returned_df,index_restriction=["smallworld"],
                            column_restriction=[],
                            value_restriction="n_triangles>100")

"""
Here we see the probability fo reshuffling results in higher n_triangles

"""

filtered_df
# Out:
#                                               graphs    n    k    p  n_nodes  \
# 0  watts_strogatz_graph_smallworld_random_locatio...   50  8.0  0.1       50
# 1  watts_strogatz_graph_smallworld_random_locatio...   50  8.0  0.4       50
# 2  watts_strogatz_graph_smallworld_random_locatio...  100  8.0  0.1      100
# 3  watts_strogatz_graph_smallworld_random_locatio...  100  8.0  0.4      100
# 4  watts_strogatz_graph_smallworld_random_locatio...  150  4.0  0.1      150
# 5  watts_strogatz_graph_smallworld_random_locatio...  150  8.0  0.1      150
# 6  watts_strogatz_graph_smallworld_random_locatio...  150  8.0  0.4      150
# 7  watts_strogatz_graph_smallworld_random_locatio...  150  8.0  0.6      150
#
#    n_edges  n_triangles  transitivity  node_connectivity  size_maximum_clique  \
# 0      200        228.4      0.483302                5.8                  5.0
# 1      200        111.0      0.226163                4.8                  4.6
# 2      400        443.6      0.468900                5.6                  5.0
# 3      400        176.0      0.180743                4.8                  4.6
# 4      300        110.0      0.355642                2.0                  3.4
# 5      600        678.6      0.478514                5.4                  5.4
# 6      600        229.8      0.156882                4.2                  4.4
# 7      600        121.8      0.081825                4.0                  4.2
#
#    n_maximal_cliques  min_weighted_vertex_cover_len  tree_number  \
# 0               76.2                           50.0         16.0
# 1              115.6                           48.8         22.0
# 2              155.6                          100.0         23.0
# 3              248.4                           98.4         42.2
# 4              167.0                          150.0         16.4
# 5              227.0                          149.6         33.0
# 6              389.0                          148.4         62.2
# 7              445.8                          146.0         67.0
#
#                                         graph_type
# 0  watts_strogatz_graph_smallworld_random_location
# 1  watts_strogatz_graph_smallworld_random_location
# 2  watts_strogatz_graph_smallworld_random_location
# 3  watts_strogatz_graph_smallworld_random_location
# 4  watts_strogatz_graph_smallworld_random_location
# 5  watts_strogatz_graph_smallworld_random_location
# 6  watts_strogatz_graph_smallworld_random_location
# 7  watts_strogatz_graph_smallworld_random_location

# %% [markdown]
# # Comparing the Erdos-Renyi and the Smallworld

# %%
from graph_experiments_utils import *

functions_list = [n_triangles,transitivity,
     node_connectivity,
     size_maximum_clique,
     n_maximal_cliques,
     min_weighted_vertex_cover_len,tree_number]

graph_function = watts_strogatz_graph_smallworld_random_location

loop_1 = dict(n=[50,100,150])
loop_2 = dict(p=[0.01,0.03,0.05])
loop_3 = dict(k=[8,16])
iterable_loops = [loop_1,loop_2,loop_3]
n_iterations = 5


data_structure_smallworld = run_graph_experiment(graph_function,
                        functions_list,
                        iterable_loops,
                         n_iterations,
                         func_args = dict()
                                     )

data_structure_total = dict()
dict_to_combine = [data_structure_erdos,data_structure_smallworld,]
for dk in dict_to_combine:
    data_structure_total.update(dk)
df = table_comparison_statistics(data_structure_total)

returned_df, (fig,ax) = graph_experiments_utils.plot_df_values(df,index_restriction=[],
               x_column="n_edges",
               y_column = "n",
               z_column = "n_triangles",
                grouping=dict(graph_type=dict(exact=[])),
               plot_type="scatter",
               title="Triangles vs. Node Count,Edge_Count",
              #value_restriction=" n_edges > 10 ",
                return_fig_ax=True,
                return_plotted_df_table=True
                                )
# Out:
# returning figure and ax

# %%
# Update the plot
returned_df, (fig,ax) = graph_experiments_utils.plot_df_values(df,index_restriction=[],
               x_column = "n",
               y_column = "n_triangles",
                grouping=dict(graph_type=dict(exact=[])),
               plot_type="scatter",
               title="Triangles vs. Node Count",
              #value_restriction=" n_edges > 10 ",
                return_fig_ax=True,
                return_plotted_df_table=True
                                )
# Out:
# returning figure and ax

# %% [markdown]
# # How Does the triangles compare to the opportunity to triangles (transitivity)

# %%
returned_df, (fig,ax) = graph_experiments_utils.plot_df_values(df,index_restriction=[],
               x_column="n_edges",
               y_column = "n",
               z_column = "transitivity",
                grouping=dict(graph_type=dict(exact=[])),
               plot_type="scatter",
               title="Transitivity vs. Node Count, Edge_Count",
              #value_restriction=" n_edges > 10 ",
                return_fig_ax=True,
                return_plotted_df_table=True
                                )
# Out:
# returning figure and ax
